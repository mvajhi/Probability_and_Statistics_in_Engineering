# %% [markdown]
# # part 1

# %%
import numpy as np

# %%
n = 250
p = 0.008
m = 100000

# %%
bin = np.random.binomial(n, p, m)

# %%
poi = np.random.poisson(n * p, m)

# %%
N = np.random.normal(2, 1.984, m)

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats
import math

# %%
mu = 2
variance = 1.984
sigma = math.sqrt(variance)

# %%
fig, ax = plt.subplots()
# count, bins, ignored = ax.hist(bin, density=True, label="bin")
# count, bins, ignored = ax.hist(poi, density=True, label="poi")
# count, bins, ignored = ax.hist(N, density=True, label="norm")


x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
norm, = ax.plot(x, stats.norm.pdf(x, mu, sigma))

# x = np.arange(0, 100, 1)
# y = stats.poisson.pmf(x, mu=mu, loc=40)
# plt.plot(x, y)

ax.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
