# %% [markdown]
# # pre processing

# %% [markdown]
# output:
#     books_train_csv and books_test_csv
#
#         [
#             {
#                 "title": name of book (normalized),
#                 "description": description of book (tokenized & normalized& remove Word that do not contain letters),
#                 "categories" : categories of book (normalized)
#             },
#             .
#             .
#             .,
#             {...}
#         ]

# %%
import csv
from hazm import Normalizer, sent_tokenize, word_tokenize

# %% [markdown]
# ### importing csv

# %%
books_train_csv = list()

with open("books_train.csv") as file:
    reader = csv.DictReader(file)
    books_train_csv = [i for i in reader]

# %%
books_test_csv = list()

with open("books_test.csv") as file:
    reader = csv.DictReader(file)
    books_test_csv = [i for i in reader]

# %%
books_train_csv
books_test_csv

# %% [markdown]
# ### Normalizing

# %%
normalizer = Normalizer()
books_train_csv = [{j : normalizer.normalize(i[j]).replace("\u200c", " ") for j in i.keys()} for i in books_train_csv]
books_test_csv = [{j : normalizer.normalize(i[j]).replace("\u200c", " ") for j in i.keys()} for i in books_test_csv]

# %%
books_train_csv
books_test_csv

# %% [markdown]
# ### tokenize

# %%
def has_farsi_letters(text : str) -> bool:
    for char in text:
            if char.isalpha() and ord(char) >= 0x0600 and ord(char) <= 0x06FF:
                   return True
    return False

# %%
def is_valid_word(word : str) -> bool:
    if has_farsi_letters(word):
        return True
    return False

# %%
def tokenize_str(txt : str) -> list(str()):
    token = list()
    for sent in sent_tokenize(txt):
        for word in word_tokenize(sent):
            if is_valid_word(word):
                token.append(word)
    return token

# %%
for i in range(len(books_train_csv)):
    for j in {"description"}:
        books_train_csv[i][j] = tokenize_str(books_train_csv[i][j])

for i in range(len(books_test_csv)):
    for j in {"description"}:
        books_test_csv[i][j] = tokenize_str(books_test_csv[i][j])

# %%
books_train_csv
books_test_csv

# %% [markdown]
# # processing

# %% [markdown]
# ### count words per category

# %%
all_words = list()
for i in books_train_csv:
    all_words.extend(i["description"])

# %%
categories_data = {"total" : {"total" : 0 , **{word : 0 for word in all_words}}}
for book in books_train_csv:
    if book["categories"] not in categories_data.keys():
        categories_data[book["categories"]] = {"total" : 0, **{word : 0 for word in all_words}}
    for word in book["description"]:
        categories_data[book["categories"]][word] += 1
        categories_data[book["categories"]]["total"] += 1
        categories_data["total"][word] += 1
        categories_data["total"]["total"] += 1

# %%
categories_data
# Out:
# {'total': {'total': 496563,
#   'ساختار': 50,
#   'نظریه': 172,
#   'های': 6139,
#   'جامعه': 648,
#   'شناسی': 378,
#   'ایران': 359,
#   'نوشته': 936,
#   'ابوالفضل': 8,
#   'رمضانی': 7,
#   'دربردارنده': 49,
#   'درباره': 837,
#   'از': 12430,
#   'منظر': 76,
#   'اندیشمندانی': 2,
#   'همچون': 140,
#   'جواد': 8,
#   'طباطبایی': 14,
#   'همایون': 13,
#   'کاتوزیان': 1,
#   'احمد': 80,
#   'اشرف': 12,
#   'پرویز': 7,
#   'پیران': 3,
#   'حسین': 138,
#   'بشیریه': 1,
#   'و': 26459,
#   'است': 7181,
#   'در': 14150,
#   'بخشی': 549,
#   'کتاب': 4068,
#   'می': 13917,
#   'خوانیم': 477,
#   'تحلیل': 188,
#   'تاکید': 36,
#   'بیشتر': 363,
#   'بر': 1489,
#   'خلاصه': 66,
#   'سازی': 127,
#   'دقیق': 76,
#   'ها': 3776,
#   'با': 5571,
#   'شکافتن': 1,
#   'اجزا': 4,
#   'عناصر': 38,
#   'آنها': 725,
#   'تلاش': 214,
#   'شود': 1554,
#   'تا': 1784,
#   'جایی': 135,
#   'که': 11073,
#   'امکان': 89,
#   'دارد': 1226,
#   'کمترین': 26,
#   'چیزی': 321,
#   'قلم': 306,
#   'نیفتد': 2,
#   'هدف': 205,
#   'این': 7594,
#   'برای': 2931,
#   'تجزیه': 29,
#   'شناختی': 103,
#   'موجود': 111,
#   'به': 14071,
#   'اصلی': 297,
#   'منظور': 59,
#   'کمک': 258,
#   'تحقیقات': 58,
#   'تجربی': 17,
#   'آزمون': 23,
#   'همین': 471,
#   'اینها': 18,
#   'رویکردهایی': 1,
#   'نسبت': 142,
#   'خود': 1926,
#   'هستند': 450,
#   'حاضر': 227,
#   'تحقیق': 103,
#   'پذیری': 41,
#   'را': 9277,
#   'تسهیل': 7,
#   'کند': 2222,
#   'علاوه': 114,
#   'شفاف': 16,
#   'کنار': 321,
#   'هم': 1874,
#   'قرار': 608,
#   'دادن': 158,
#   'ویژگی': 172,
#   'بنیادی': 21,
#   'حاکم': 43,
#   'روابط': 122,
#   'اجتماعی': 642,
#   'دست': 853,
#   'یابیم': 10,
#   'تنها': 324,
#   'صورت': 311,
#   'توانیم': 50,
#   'اندیشه': 142,
#   'سطحی': 16,
#   'رهایی': 28,
#   'پیدا': 270,
#   'کنیم': 392,
#   'دانش': 140,
#   'تولید': 92,
#   'شده': 786,
#   'اصلاح': 44,
#   'امور': 64,
#   'استفاده': 324,
#   'نشان': 278,
#   'اجازه': 64,
#   'دهد': 710,
#   'خودش': 347,
#   'سخن': 150,
#   'بگوید': 47,
#   'دلیل': 223,
#   'نیازی': 21,
#   'نقد': 117,
#   'تحلیلی': 33,
#   'ندیدم': 4,
#   'هر': 1149,
#   'چند': 382,
#   'قلت': 3,
#   'کارهای': 95,
#   'تحقیقی': 9,
#   'روی': 710,
#   'انتقادی': 51,
#   'نیز': 687,
#   'وجود': 446,
#   'ندارد': 191,
#   'بی': 819,
#   'مایه': 53,
#   'نادیده': 24,
#   'گرفتن': 73,
#   'پیشین': 18,
#   'کمکی': 9,
#   'پیشبرد': 14,
#   'پردازی': 30,
#   'نمی': 1159,
#   'فرهنگ': 367,
#   'کانادا': 14,
#   'مجموعه': 1167,
#   'کشورها': 19,
#   'ی': 1990,
#   'نشر': 59,
#   'الهدی': 3,
#   'معرفی': 154,
#   'کشور': 213,
#   'مردم': 418,
#   'سازمان': 258,
#   'هاو': 2,
#   'نهادهای': 33,
#   'سیاسی': 267,
#   'فرهنگی': 318,
#   'پردازد': 323,
#   'پرسش': 104,
#   'مختلفی': 46,
#   'زندگی': 1556,
#   'شخصیت': 283,
#   'امام': 378,
#   'مهدی': 103,
#   'عج': 51,
#   'اذهان': 9,
#   'هایی': 869,
#   'گاه': 122,
#   'میان': 478,
#   'آموزان': 21,
#   'دانشجویان': 90,
#   'دیگر': 897,
#   'اقشار': 10,
#   'مطرح': 184,
#   'دغدغه': 60,
#   'ذهنی': 64,
#   'تبدیل': 169,
#   'توجه': 267,
#   'فراوانی': 42,
#   'کسانی': 183,
#   'مجالس': 15,
#   'محافل': 12,
#   'مختلف': 339,
#   'طرح': 81,
#   'پردازند': 15,
#   'موعود': 21,
#   'ابراهیم': 38,
#   'شفیعی': 27,
#   'سروستانی': 28,
#   'چهارده': 43,
#   'مهدویت': 35,
#   'پاسخ': 169,
#   'فلسفه': 90,
#   'غیبت': 66,
#   'صغری': 3,
#   'جزیره': 32,
#   'خضرا': 2,
#   'یاران': 10,
#   'دوران': 212,
#   'وقت': 266,
#   'ظهور': 78,
#   'فتنه': 10,
#   'دجال': 7,
#   'خروج': 18,
#   'روایات': 62,
#   'متعددی': 29,
#   'گریزناپذیر': 2,
#   'بودن': 187,
#   'عنوان': 535,
#   'یکی': 836,
#   'رویدادهای': 21,
#   'آخرالزمان': 7,
#   'یا': 1116,
#   'نشانه': 73,
#   'قیامت': 24,
#   'تأکید': 31,
#   'شده_است': 702,
#   'جمله': 178,
#   'روایتی': 42,
#   'امیرمؤمنان': 11,
#   'علی': 345,
#   'ع': 287,
#   'پیامبر': 86,
#   'گرامی': 15,
#   'اسلام': 190,
#   'ص': 78,
#   'نقل': 57,
#   'پیش': 571,
#   'ساعت': 119,
#   'ده': 172,
#   'رویداد': 15,
#   'سفیانی': 2,
#   'برخی': 230,
#   'حتمی': 6,
#   'مانند': 262,
#   'دانسته': 21,
#   'انکار': 11,
#   'آن': 3935,
#   'کفر': 6,
#   'شمار': 97,
#   'آمده_است': 112,
#   'توان': 310,
#   'روایت': 409,
#   'نبوی': 6,
#   'زیر': 244,
#   'اشاره': 129,
#   'کرد': 1356,
#   'کس': 105,
#   'منکر': 11,
#   'آنچه': 202,
#   'محمد': 175,
#   'نازل': 11,
#   'گشته': 3,
#   'کافر': 7,
#   'نزول': 9,
#   'عیسی': 14,
#   'موج': 25,
#   'دریا': 61,
#   'مهری': 11,
#   'ماهوتی': 3,
#   'تصویرگری': 116,
#   'عاطفه': 13,
#   'ملکی': 18,
#   'جو': 39,
#   'داستانی': 297,
#   'مصور': 31,
#   'کودکان': 286,
#   'جلدی': 59,
#   'چه': 884,
#   'مهربان': 43,
#   'خدا': 214,
#   'غرب': 64,
#   'دکتر': 192,
#   'اسماعیل': 36,
#   'نوعی': 92,
#   'تفاوت': 75,
#   'هستی': 99,
#   'شناسانه': 28,
#   'جهان': 443,
#   'بینی': 127,
#   'شرق': 49,
#   'مقدمه': 176,
#   'چنین': 215,
#   'خوانید': 166,
#   'اساسا': 11,
#   'پرسشی': 9,
#   'فلسفی': 64,
#   'مقام': 69,
#   'نظر': 381,
#   'ناظر': 11,
#   'درک': 164,
#   'شرایط': 145,
#   'تاریخی': 187,
#   'ویژه': 209,
#   'ای': 2367,
#   'گذار': 58,
#   'ممکن': 141,
#   'نیست': 495,
#   'نقاط': 26,
#   'عطف': 8,
#   'مهم': 350,
#   'اقوام': 21,
#   'آید': 195,
#   'گویی': 76,
#   'بدان': 32,
#   'عهدۀ': 2,
#   'عوام': 8,
#   'وظیفۀ': 2,
#   'دانشمندان': 13,
#   'اربابان': 3,
#   'فن': 24,
#   'حتی': 346,
#   'سیاست': 118,
#   'مداران': 10,
#   'بلکه': 208,
#   'متفکران': 13,
#   'صاحبان': 17,
#   'آنان': 176,
#   'مخاطب': 74,
#   'پرسشند': 1,
#   'شرط': 20,
#   'آنکه': 77,
#   'رأیشان': 1,
#   'منشأ': 6,
#   'اثر': 747,
#   'باشد': 514,
#   'جهت': 133,
#   'گیری': 166,
#   'بزرگ': 510,
#   'همه': 802,
#   'چیز': 205,
#   'تمدن': 62,
#   'مناسبات': 25,
#   'معلوم': 35,
#   'سازد': 91,
#   'سرنوشت': 50,
#   'یک': 2651,
#   'قوم': 33,
#   'رقم': 29,
#   'زند': 109,
#   'مسیر': 117,
#   'طی': 101,
#   'طریق': 98,
#   'نماید': 66,
#   'چگونه': 271,
#   'عرصۀ': 8,
#   'حیات': 81,
#   'روشن': 162,
#   'نگارنده': 17,
#   'ضمن': 55,
#   'ضرورت': 52,
#   'سعی': 183,
#   'بیان': 279,
#   'جایگاه': 125,
#   'موضوع': 394,
#   'کلیۀ': 1,
#   'ساکنان': 13,
#   'مشرق': 11,
#   'زمین': 202,
#   'اسلامی': 277,
#   'شیعی': 19,
#   'مذهب': 39,
#   'شایسته': 25,
#   'تر': 473,
#   'امر': 74,
#   'شناسد': 16,
#   'زیرا': 123,
#   'سایر': 66,
#   'ملل': 26,
#   'شرقی': 45,
#   'چین': 62,
#   'هند': 15,
#   'ژاپن': 32,
#   'رویارویی': 20,
#   'متحمل': 7,
#   'خسارات': 2,
#   'بسیار': 354,
#   'شده_اند': 192,
#   'لیکن': 3,
#   'حسب': 3,
#   'سابقه': 24,
#   'جان': 174,
#   'مایۀ': 4,
#   'فرهنگیشان': 1,
#   'تجدید': 21,
#   'برخوردار': 50,
#   'نیستند': 54,
#   'نظام': 140,
#   'فکری': 76,
#   'نظری': 57,
#   'فاقد': 9,
#   'رویکردی': 29,
#   'بنیادین': 19,
#   'جدی': 65,
#   'آینده': 157,
#   'اند': 228,
#   'عموم': 20,
#   'منسوخ': 5,
#   'ممسوخ': 1,
#   'آسیایی': 10,
#   'دربارۀ': 28,
#   'کیفیت': 51,
#   'برکشیدن': 1,
#   'بنای': 13,
#   'تمدنی': 16,
#   'تنظیم': 41,
#   'معاملات': 13,
#   'فردی': 147,
#   'جمعی': 48,
#   'مبنای': 24,
#   'زیرساخت': 5,
#   'ساکتند': 1,
#   'توانایی': 107,
#   'ایجاد': 249,
#   'جریان': 89,
#   'نقطه': 75,
#   'محروم': 12,
#   'نموده_است': 27,
#   'مسپله': 1,
#   'زدگی': 10,
#   'پذیرش': 17,
#   'غربی': 58,
#   'تجدد': 9,
#   'پس': 614,
#   'مشروطه': 19,
#   'سه': 424,
#   'اساسی': 77,
#   'انسان': 535,
#   'طبیعت': 37,
#   'نهایت': 101,
#   'علم': 147,
#   'جدید': 196,
#   'کرده': 332,
#   'دیدگاه': 131,
#   'چالش': 90,
#   'کشیده_است': 21,
#   'خارج': 76,
#   'خط': 84,
#   'داستان': 2422,
#   'کوتاهی': 106,
#   'محمود': 46,
#   'راجی': 1,
#   'نویسنده': 1073,
#   'معاصر': 221,
#   'ایرانی': 310,
#   'نگاهی': 115,
#   'گذرا': 5,
#   'بدون': 232,
#   'دقت': 48,
#   'راننده': 27,
#   'مسافرش': 3,
#   'کنم': 387,
#   'هیچ': 476,
#   'خاصی': 59,
#   'توجهی': 28,
#   'ندارم': 35,
#   'قصد': 66,
#   'ماشین': 68,
#   'آدم': 279,
#   'گذرانم': 1,
#   'ولی': 319,
#   'گوشم': 12,
#   'مشاجره': 5,
#   'لفظی': 5,
#   'بین': 382,
#   'دو': 783,
#   'جلب': 38,
#   'وقتی': 395,
#   'نگاهم': 12,
#   'دوباره': 137,
#   'برمی': 106,
#   'گردد': 150,
#   'متوجه': 117,
#   'شوم': 54,
#   'شدت': 46,
#   'کنند': 815,
#   'نگاهشان': 4,
#   'سمت': 139,
#   'من': 1183,
#   'دختر': 197,
#   'همراه': 270,
#   'مسافر': 17,
#   'گریه': 52,
#   'مرا': 131,
#   'پاید': 2,
#   'نزدیک': 163,
#   'پرخاش': 2,
#   'گوید': 279,
#   'غلط': 16,
#   'کنی': 126,
#   'پول': 181,
#   'نداشتی': 2,
#   'راه': 506,
#   'کشاندی': 1,
#   'آوردی': 3,
#   'خانم': 118,
#   'شدید': 28,
#   'شما': 799,
#   'فرض': 34,
#   'کن': 119,
#   'برادر': 53,
#   'پدر': 222,
#   'چرا': 252,
#   'باعث': 147,
#   'آبروی': 5,
#   'خواهرت': 1,
#   'شوی': 9,
#   'برادری': 2,
#   'خواهری': 1,
#   'کشکی': 2,
#   'اگر': 563,
#   'مسافرهایم': 1,
#   'خواهر': 41,
#   'برادرم': 11,
#   'باشند': 113,
#   'بچه': 239,
#   'هایم': 41,
#   'گرسنگی': 6,
#   'میرند': 7,
#   'حالا': 204,
#   'هزارتا': 3,
#   'ادا': 5,
#   'آورد': 202,
#   'تو': 507,
#   'بیا': 16,
#   'کرایه': 11,
#   'برابر': 108,
#   'بده': 36,
#   'همدیگر': 13,
#   'خطاب': 18,
#   'نگاه': 283,
#   'شان': 258,
#   'دارند': 370,
#   'حرف': 216,
#   'زنند': 27,
#   'شاید': 246,
#   'خواهند_که': 3,
#   'مداخله': 12,
#   'دعوا': 9,
#   'تمام': 403,
#   'فکرم': 2,
#   'کاملا': 96,
#   'رو': 484,
#   'حاجی': 15,
#   'آقا': 52,
#   'بگویید': 4,
#   'قبل': 159,
#   'بپرسم': 5,
#   'بگویم': 34,
#   'علت': 64,
#   'توضیح': 99,
#   'او': 2653,
#   'خواهد_که': 5,
#   'اش': 725,
#   'صرف': 75,
#   'پرسم': 4,
#   'قدر': 102,
#   'لاک': 11,
#   'صورتی': 26,
#   'جلال': 22,
#   'آل': 46,
#   'فعال': 37,
#   'مطالعه': 234,
#   'اضافه': 60,
#   'زیادی': 225,
#   'سرمایه': 256,
#   'گذاری': 135,
#   'دنیا': 340,
#   'ما': 999,
#   'دوره': 180,
#   'خارق': 15,
#   'العاده': 52,
#   'تاریخ': 304,
#   'بشر': 84,
#   'هزاران': 22,
#   'زمینه': 300,
#   'فراهم': 92,
#   'بسیاری': 308,
#   'سردرگم': 7,
#   'کننده': 128,
#   'فهم': 68,
#   'دشوار': 32,
#   'مارک': 39,
#   'ویکتو': 1,
#   'ر': 3,
#   'هانسن': 15,
#   'صوتی': 227,
#   'راهبردهای': 17,
#   'کسب': 346,
#   'وکار': 101,
#   'نخستین': 142,
#   'پایه': 64,
#   'ترین': 510,
#   'ابزار': 33,
#   'رشد': 157,
#   'ثروت': 69,
#   'حجم': 19,
#   'مقداری': 9,
#   'بیش': 269,
#   'اکنون': 99,
#   'افزایش': 92,
#   'دهید': 85,
#   'زیباترین': 19,
#   'وجوه': 12,
#   'تجارت': 102,
#   'تماما': 5,
#   'اساس': 159,
#   'افراد': 312,
#   'اجرا': 44,
#   'شکل': 218,
#   'روز': 484,
#   'افزون': 17,
#   'دهکده': 26,
#   'جهانی': 239,
#   'زمانی': 194,
#   'نوع': 125,
#   'بیگانه': 38,
#   'ریشه': 66,
#   'مشکلات': 96,
#   'منازعات': 4,
#   'نبود': 193,
#   'صحیح': 45,
#   'یکدیگر': 95,
#   'شناخت': 131,
#   'ناقص': 7,
#   'مشترک': 55,
#   'جوامع': 64,
#   'باز': 287,
#   'گفتمان': 72,
#   'نظرات': 19,
#   'رسانه': 316,
#   'بریتانیا': 33,
#   'چهره': 107,
#   'آیینه': 10,
#   'مطبوعات': 22,
#   'توسط': 139,
#   'آقایان': 4,
#   'پل': 50,
#   'بیکر': 2,
#   'کاستاس': 1,
#   'گابریلاتوس': 1,
#   'تونی': 10,
#   'مک': 42,
#   'انری': 1,
#   'نوشته_شده_است': 86,
#   'بهر': 1,
#   'ازپژوهش': 1,
#   'رایزنی': 1,
#   'جمهوری': 36,
#   'نظران': 22,
#   'بزرگان': 39,
#   'صاحب': 96,
#   'حوزه': 305,
#   'آگاهی': 60,
#   'خوانندگان': 58,
#   'موثر': 36,
#   'مفید': 82,
#   'واقع': 160,
#   'اختلالات': 4,
#   'مصرف': 92,
#   'مواد': 24,
#   'مشاوره': 29,
#   'اعتیاد': 19,
#   'فورد': 10,
#   'بروکس': 4,
#   'بیل': 19,
#   'ام': 180,
#   'سی': 108,
#   'هنری': 82,
#   'کتابی': 264,
#   'آخرین': 117,
#   'روش': 305,
#   'ترک': 74,
#   'موادمخدر': 1,
#   'الکل': 9,
#   'آشنا': 165,
#   'نهایی': 27,
#   'نگارش': 82,
#   'رفتارهای': 39,
#   'مشکل': 72,
#   'ساز': 55,
#   'اعتیادآور': 3,
#   'تغییر': 183,
#   'سازگارانه': 2,
#   'آموخته_شود': 3,
#   'پروفسور': 25,
#   'دانشکده': 21,
#   'کارمند': 25,
#   'دانشگاه': 232,
#   'شیپنزبورگ': 1,
#   'پنسیلوانیا': 2,
#   'ایشان': 121,
#   'برنامه': 207,
#   'بهداشت': 6,
#   'روانی': 44,
#   'بالینی': 1,
#   'همچنین': 200,
#   'عملی': 81,
#   'کارآموزی': 1,
#   'تخصصی': 52,
#   'دپارتمان': 5,
#   'ریزی': 96,
#   'سرپرستی': 9,
#   'سرویس': 8,
#   'آموزشی': 111,
#   'درمان': 36,
#   'جویان': 7,
#   'درکمپ': 1,
#   'آژانس': 10,
#   'مدارس': 16,
#   'منطقه': 42,
#   'جنوب': 21,
#   'مرکزی': 20,
#   'ارائه': 223,
#   'داد': 354,
#   'دکترای': 11,
#   'رشته': 178,
#   'ویلیام': 20,
#   'ماری': 18,
#   'فوق': 62,
#   'لیسانس': 15,
#   'ویرجینیا': 6,
#   'گرایش': 32,
#   'روان': 187,
#   'ریچموند': 1,
#   'دریافت': 97,
#   'کرده_است': 447,
#   'رئیس': 59,
#   'تحصیلات': 35,
#   'تکمیلی': 7,
#   'پژوهشی': 68,
#   'تگزاس': 1,
#   'آموزش': 221,
#   'داکوتای': 1,
#   'جنوبی': 27,
#   'مدت': 112,
#   'سال': 1168,
#   'مشاور': 13,
#   'بوده_است': 147,
#   'تجربه': 159,
#   'گروهی': 69,
#   'زوجی': 9,
#   'خانوادگی': 44,
#   'سوء': 17,
#   'دانشگاهها': 1,
#   'سلامتی': 16,
#   'مراکز': 23,
#   'جست': 44,
#   'وجوی': 19,
#   'معنا': 52,
#   'رهیافتی': 1,
#   'معناشناختی': 1,
#   'اطلاعات': 127,
#   'نرگس': 17,
#   'نشاط': 4,
#   'امروزه': 64,
#   'هرکس': 18,
#   'محتوا': 22,
#   'متن': 107,
#   'سروکار': 13,
#   'نیازمند': 30,
#   'ابزاری': 17,
#   'علمی': 162,
#   'بتواند': 61,
#   'پیام': 65,
#   'مخابره': 1,
#   'انتقالی': 4,
#   'داشته_باشد': 107,
#   'سوال': 46,
#   'پرسیده_شود': 6,
#   'احساس': 168,
#   'نیاز': 139,
#   'بوجود': 5,
#   'سبب': 64,
#   'تشدید': 3,
#   'پیامی': 6,
#   'ارسال': 7,
#   'نهفته': 25,
#   'باید': 657,
#   'موضوعی': 48,
#   'برخورد': 70,
#   'معناشناسی': 3,
#   'گونه': 237,
#   'مورد': 506,
#   'پی': 128,
#   'کشف': 63,
#   'چگونگی': 134,
#   'سازماندهی': 21,
#   'بررسی': 475,
#   'تاثیر': 91,
#   'معنایی': 25,
#   'گیرنده': 8,
#   'خواننده': 151,
#   'شنونده': 13,
#   'دانست': 94,
#   'کجا': 76,
#   'سپس': 136,
#   'بازتولید': 7,
#   'تفسیر': 77,
#   'فهمیده': 7,
#   'بنابراین': 90,
#   'مساله': 18,
#   'محوری': 30,
#   'معناست': 7,
#   'مستقیم': 35,
#   'غیرمستقیم': 11,
#   'پیوند': 51,
#   'جستجوی': 24,
#   'امکانات': 15,
#   'تحقق': 43,
#   'پیوستگی': 8,
#   'ماهیت': 50,
#   'آزمایش': 20,
#   'اعتبار': 19,
#   'دانیم': 17,
#   'آیا': 208,
#   'مفهوم': 133,
#   'رها': 51,
#   'یعنی': 253,
#   'بدانیم': 21,
#   'آنجا': 136,
#   'خواهیم_معنا': 1,
#   'قیمتی': 7,
#   'قیمت': 39,
#   'خواهدشد': 4,
#   'مبارزه': 63,
#   'راهبرد': 6,
#   'آغاز': 222,
#   'اندوه': 25,
#   'بالابان': 5,
#   'رجبی': 3,
#   'مناسب': 116,
#   'گروه': 172,
#   'سنی': 34,
#   'اولین': 198,
#   'جشنواره': 19,
#   'سپیدار': 1,
#   'برگزیده': 84,
#   'انتخاب': 198,
#   'قاچاق': 7,
#   'غیر': 102,
#   'قانونی': 24,
#   'پرندگان': 6,
#   'ارزشمندی': 17,
#   'کشورهای': 73,
#   'حاشیه': 22,
#   'خلیج': 3,
#   'فارس': 9,
#   'مندو': 2,
#   'پسری': 38,
#   'نوجوان': 82,
#   'لنجی': 1,
#   'نام': 654,
#   'شبوت': 1,
#   'ناخدا': 8,
#   'سمیر': 3,
#   'کار': 954,
#   'روزهایی': 14,
#   'شارجه': 1,
#   'بروند': 22,
#   'مسافری': 5,
#   'غریبه': 28,
#   'جعبه': 18,
#   'مرموز': 12,
#   'همسفر': 4,
#   'تعدادی': 30,
#   'پرنده': 35,
#   'داخل': 78,
#   'زندانی': 33,
#   'دلش': 37,
#   'خواهد_پرنده': 1,
#   'نجات': 62,
#   'همکاری': 46,
#   'کردن': 354,
#   'همکاران': 8,
#   'دیگرش': 15,
#   'مرد': 294,
#   'خشمگین': 10,
#   'اما': 1108,
#   'آخر': 99,
#   'ماموران': 4,
#   'گشت': 52,
#   'دریایی': 26,
#   'خبر': 105,
#   'قاچاقچی': 1,
#   'بگیرند': 29,
#   'دهند': 200,
#   'زیبا': 81,
#   'اصطلاحات': 25,
#   'کلمات': 47,
#   'بومی': 41,
#   'خوبی': 180,
#   'جغرافیای': 16,
#   'مهرتابناک': 1,
#   'جلد': 270,
#   'اول': 390,
#   'شمه': 5,
#   'احوالات': 1,
#   'آیت': 66,
#   'الله': 214,
#   'حاج': 25,
#   'سیدعلی': 5,
#   'قاضی': 16,
#   'آثار': 352,
#   'علامه': 41,
#   'محمدحسین': 17,
#   'حسینی': 65,
#   'طهرانی': 20,
#   'اضافاتی': 1,
#   'سیدمحمدمحسن': 3,
#   'تهرانی': 20,
#   'مدیریت': 388,
#   'خدمات': 53,
#   'مشتری': 123,
#   'ژاک': 11,
#   'هاروویتز': 3,
#   'استاد': 223,
#   'بازاریابی': 196,
#   'الملل': 14,
#   'لوزان': 1,
#   'سوییس': 2,
#   'تخصص': 10,
#   'وی': 194,
#   'ارتقای': 25,
#   'رضایت': 30,
#   'برارائه': 1,
#   'تفکیک': 9,
#   'تقویت': 50,
#   'وفاداری': 12,
#   'نتیجه': 134,
#   'خدماتی': 11,
#   'مدرسه': 115,
#   'عالی': 88,
#   'بازرگانی': 29,
#   'پاریس': 39,
#   'فرانسه': 97,
#   'فارغ': 31,
#   'التحصیل': 17,
#   'شد': 1063,
#   'دکترا': 4,
#   'کلمبیا': 10,
#   'نیویورک': 56,
#   'پاداش': 7,
#   'تحصیلی': 16,
#   'شامل': 175,
#   'هزینه': 54,
#   'ساموئل': 11,
#   'بردنفمن': 1,
#   'کلی': 120,
#   'آموزشگاه': 2,
#   'امریکا': 60,
#   'فکر': 432,
#   'توسعه': 164,
#   'فعالیت': 147,
#   'مجال': 6,
#   'اندیشیدن': 12,
#   'مزایای': 15,
#   'طولی': 3,
#   'اضافی': 6,
#   'دستگاه': 35,
#   'بخرید': 3,
#   'کارش': 37,
#   'محصولاتی': 2,
#   'معین': 15,
#   'مشتریانی': 1,
#   'فروشنده': 28,
#   'فروش': 211,
#   'تواند': 351,
#   'پیشنهادش': 2,
#   'قراردادهای': 2,
#   'مربوط': 134,
#   'تعمیرات': 1,
#   'احتیاطی': 3,
#   'مستمر': 11,
#   'مشتریان': 55,
#   'درنهایت': 12,
#   'محصولات': 36,
#   'تولیدشده': 1,
#   'وسیله': 45,
#   'رأیت': 1,
#   'دین': 175,
#   'تألیف': 36,
#   'اکبر': 16,
#   'عالمیان': 1,
#   'رفتار': 163,
#   'العظمی': 12,
#   'بروجردی': 8,
#   'تحریر': 20,
#   'درآمده': 26,
#   'بخش': 494,
#   'ابتدا': 108,
#   'مرجع': 9,
#   'عظیم': 25,
#   'القدر': 4,
#   'تولد': 36,
#   'رحلت': 6,
#   'دوم': 301,
#   'رابطه': 159,
#   'مقوله': 37,
#   'محقق': 27,
#   'سوم': 169,
#   'رهبری': 156,
#   'امت': 24,
#   ...},
#  'جامعه شناسی': {'total': 93900,
#   'ساختار': 33,
#   'نظریه': 130,
#   'های': 1517,
#   'جامعه': 453,
#   'شناسی': 292,
#   'ایران': 190,
#   'نوشته': 156,
#   'ابوالفضل': 3,
#   'رمضانی': 1,
#   'دربردارنده': 9,
#   'درباره': 218,
#   'از': 2270,
#   'منظر': 30,
#   'اندیشمندانی': 2,
#   'همچون': 45,
#   'جواد': 2,
#   'طباطبایی': 2,
#   'همایون': 1,
#   'کاتوزیان': 1,
#   'احمد': 8,
#   'اشرف': 4,
#   'پرویز': 2,
#   'پیران': 2,
#   'حسین': 9,
#   'بشیریه': 1,
#   'و': 5589,
#   'است': 1380,
#   'در': 3281,
#   'بخشی': 90,
#   'کتاب': 838,
#   'می': 2065,
#   'خوانیم': 48,
#   'تحلیل': 103,
#   'تاکید': 13,
#   'بیشتر': 74,
#   'بر': 376,
#   'خلاصه': 14,
#   'سازی': 47,
#   'دقیق': 21,
#   'ها': 847,
#   'با': 996,
#   'شکافتن': 1,
#   'اجزا': 4,
#   'عناصر': 16,
#   'آنها': 156,
#   'تلاش': 62,
#   'شود': 296,
#   'تا': 263,
#   'جایی': 13,
#   'که': 1833,
#   'امکان': 27,
#   'دارد': 272,
#   'کمترین': 7,
#   'چیزی': 53,
#   'قلم': 48,
#   'نیفتد': 1,
#   'هدف': 65,
#   'این': 1657,
#   'برای': 519,
#   'تجزیه': 15,
#   'شناختی': 81,
#   'موجود': 36,
#   'به': 2672,
#   'اصلی': 88,
#   'منظور': 12,
#   'کمک': 50,
#   'تحقیقات': 23,
#   'تجربی': 14,
#   'آزمون': 12,
#   'همین': 77,
#   'اینها': 6,
#   'رویکردهایی': 1,
#   'نسبت': 47,
#   'خود': 360,
#   'هستند': 105,
#   'حاضر': 84,
#   'تحقیق': 46,
#   'پذیری': 17,
#   'را': 1425,
#   'تسهیل': 3,
#   'کند': 383,
#   'علاوه': 35,
#   'شفاف': 4,
#   'کنار': 33,
#   'هم': 249,
#   'قرار': 133,
#   'دادن': 25,
#   'ویژگی': 60,
#   'بنیادی': 14,
#   'حاکم': 18,
#   'روابط': 46,
#   'اجتماعی': 457,
#   'دست': 133,
#   'یابیم': 2,
#   'تنها': 48,
#   'صورت': 71,
#   'توانیم': 11,
#   'اندیشه': 70,
#   'سطحی': 4,
#   'رهایی': 7,
#   'پیدا': 30,
#   'کنیم': 83,
#   'دانش': 60,
#   'تولید': 40,
#   'شده': 140,
#   'اصلاح': 18,
#   'امور': 24,
#   'استفاده': 74,
#   'نشان': 57,
#   'اجازه': 9,
#   'دهد': 165,
#   'خودش': 29,
#   'سخن': 46,
#   'بگوید': 5,
#   'دلیل': 65,
#   'نیازی': 3,
#   'نقد': 55,
#   'تحلیلی': 20,
#   'ندیدم': 2,
#   'هر': 193,
#   'چند': 51,
#   'قلت': 1,
#   'کارهای': 21,
#   'تحقیقی': 6,
#   'روی': 56,
#   'انتقادی': 32,
#   'نیز': 192,
#   'وجود': 107,
#   'ندارد': 29,
#   'بی': 174,
#   'مایه': 6,
#   'نادیده': 6,
#   'گرفتن': 14,
#   'پیشین': 8,
#   'کمکی': 1,
#   'پیشبرد': 6,
#   'پردازی': 7,
#   'نمی': 112,
#   'فرهنگ': 246,
#   'کانادا': 2,
#   'مجموعه': 143,
#   'کشورها': 15,
#   'ی': 244,
#   'نشر': 17,
#   'الهدی': 2,
#   'معرفی': 52,
#   'کشور': 93,
#   'مردم': 137,
#   'سازمان': 65,
#   'هاو': 1,
#   'نهادهای': 21,
#   'سیاسی': 169,
#   'فرهنگی': 234,
#   'پردازد': 119,
#   'پرسش': 45,
#   'مختلفی': 9,
#   'زندگی': 225,
#   'شخصیت': 17,
#   'امام': 11,
#   'مهدی': 9,
#   'عج': 1,
#   'اذهان': 1,
#   'هایی': 170,
#   'گاه': 23,
#   'میان': 138,
#   'آموزان': 12,
#   'دانشجویان': 43,
#   'دیگر': 174,
#   'اقشار': 2,
#   'مطرح': 54,
#   'دغدغه': 15,
#   'ذهنی': 9,
#   'تبدیل': 42,
#   'توجه': 88,
#   'فراوانی': 14,
#   'کسانی': 36,
#   'مجالس': 1,
#   'محافل': 3,
#   'مختلف': 127,
#   'طرح': 32,
#   'پردازند': 4,
#   'موعود': 2,
#   'ابراهیم': 6,
#   'شفیعی': 12,
#   'سروستانی': 12,
#   'چهارده': 3,
#   'مهدویت': 0,
#   'پاسخ': 40,
#   'فلسفه': 49,
#   'غیبت': 6,
#   'صغری': 0,
#   'جزیره': 6,
#   'خضرا': 1,
#   'یاران': 0,
#   'دوران': 64,
#   'وقت': 12,
#   'ظهور': 15,
#   'فتنه': 1,
#   'دجال': 0,
#   'خروج': 1,
#   'روایات': 2,
#   'متعددی': 9,
#   'گریزناپذیر': 0,
#   'بودن': 50,
#   'عنوان': 161,
#   'یکی': 146,
#   'رویدادهای': 6,
#   'آخرالزمان': 0,
#   'یا': 270,
#   'نشانه': 16,
#   'قیامت': 0,
#   'تأکید': 13,
#   'شده_است': 155,
#   'جمله': 40,
#   'روایتی': 3,
#   'امیرمؤمنان': 0,
#   'علی': 25,
#   'ع': 5,
#   'پیامبر': 0,
#   'گرامی': 0,
#   'اسلام': 36,
#   'ص': 4,
#   'نقل': 15,
#   'پیش': 120,
#   'ساعت': 0,
#   'ده': 21,
#   'رویداد': 4,
#   'سفیانی': 0,
#   'برخی': 76,
#   'حتمی': 1,
#   'مانند': 61,
#   'دانسته': 5,
#   'انکار': 4,
#   'آن': 812,
#   'کفر': 0,
#   'شمار': 27,
#   'آمده_است': 31,
#   'توان': 102,
#   'روایت': 41,
#   'نبوی': 0,
#   'زیر': 23,
#   'اشاره': 35,
#   'کرد': 120,
#   'کس': 8,
#   'منکر': 2,
#   'آنچه': 51,
#   'محمد': 18,
#   'نازل': 0,
#   'گشته': 2,
#   'کافر': 0,
#   'نزول': 0,
#   'عیسی': 0,
#   'موج': 3,
#   'دریا': 0,
#   'مهری': 1,
#   'ماهوتی': 0,
#   'تصویرگری': 2,
#   'عاطفه': 3,
#   'ملکی': 0,
#   'جو': 2,
#   'داستانی': 10,
#   'مصور': 0,
#   'کودکان': 18,
#   'جلدی': 2,
#   'چه': 148,
#   'مهربان': 2,
#   'خدا': 10,
#   'غرب': 49,
#   'دکتر': 51,
#   'اسماعیل': 10,
#   'نوعی': 28,
#   'تفاوت': 22,
#   'هستی': 11,
#   'شناسانه': 18,
#   'جهان': 185,
#   'بینی': 43,
#   'شرق': 31,
#   'مقدمه': 58,
#   'چنین': 65,
#   'خوانید': 34,
#   'اساسا': 5,
#   'پرسشی': 6,
#   'فلسفی': 33,
#   'مقام': 17,
#   'نظر': 100,
#   'ناظر': 3,
#   'درک': 48,
#   'شرایط': 56,
#   'تاریخی': 88,
#   'ویژه': 55,
#   'ای': 535,
#   'گذار': 13,
#   'ممکن': 25,
#   'نیست': 102,
#   'نقاط': 10,
#   'عطف': 2,
#   'مهم': 106,
#   'اقوام': 13,
#   'آید': 36,
#   'گویی': 7,
#   'بدان': 8,
#   'عهدۀ': 1,
#   'عوام': 1,
#   'وظیفۀ': 1,
#   'دانشمندان': 7,
#   'اربابان': 3,
#   'فن': 8,
#   'حتی': 72,
#   'سیاست': 79,
#   'مداران': 9,
#   'بلکه': 67,
#   'متفکران': 9,
#   'صاحبان': 6,
#   'آنان': 39,
#   'مخاطب': 19,
#   'پرسشند': 1,
#   'شرط': 4,
#   'آنکه': 23,
#   'رأیشان': 1,
#   'منشأ': 5,
#   'اثر': 173,
#   'باشد': 108,
#   'جهت': 41,
#   'گیری': 52,
#   'بزرگ': 51,
#   'همه': 120,
#   'چیز': 23,
#   'تمدن': 48,
#   'مناسبات': 16,
#   'معلوم': 6,
#   'سازد': 25,
#   'سرنوشت': 5,
#   'یک': 342,
#   'قوم': 12,
#   'رقم': 8,
#   'زند': 14,
#   'مسیر': 19,
#   'طی': 29,
#   'طریق': 38,
#   'نماید': 18,
#   'چگونه': 68,
#   'عرصۀ': 5,
#   'حیات': 21,
#   'روشن': 33,
#   'نگارنده': 8,
#   'ضمن': 20,
#   'ضرورت': 23,
#   'سعی': 43,
#   'بیان': 68,
#   'جایگاه': 57,
#   'موضوع': 139,
#   'کلیۀ': 1,
#   'ساکنان': 1,
#   'مشرق': 5,
#   'زمین': 30,
#   'اسلامی': 57,
#   'شیعی': 4,
#   'مذهب': 11,
#   'شایسته': 7,
#   'تر': 81,
#   'امر': 25,
#   'شناسد': 2,
#   'زیرا': 32,
#   'سایر': 16,
#   'ملل': 16,
#   'شرقی': 15,
#   'چین': 26,
#   'هند': 8,
#   'ژاپن': 5,
#   'رویارویی': 3,
#   'متحمل': 2,
#   'خسارات': 2,
#   'بسیار': 71,
#   'شده_اند': 42,
#   'لیکن': 2,
#   'حسب': 3,
#   'سابقه': 10,
#   'جان': 18,
#   'مایۀ': 1,
#   'فرهنگیشان': 1,
#   'تجدید': 3,
#   'برخوردار': 15,
#   'نیستند': 14,
#   'نظام': 67,
#   'فکری': 28,
#   'نظری': 33,
#   'فاقد': 4,
#   'رویکردی': 17,
#   'بنیادین': 11,
#   'جدی': 20,
#   'آینده': 63,
#   'اند': 47,
#   'عموم': 2,
#   'منسوخ': 3,
#   'ممسوخ': 1,
#   'آسیایی': 4,
#   'دربارۀ': 15,
#   'کیفیت': 9,
#   'برکشیدن': 1,
#   'بنای': 2,
#   'تمدنی': 9,
#   'تنظیم': 11,
#   'معاملات': 2,
#   'فردی': 42,
#   'جمعی': 28,
#   'مبنای': 12,
#   'زیرساخت': 2,
#   'ساکتند': 1,
#   'توانایی': 17,
#   'ایجاد': 55,
#   'جریان': 28,
#   'نقطه': 10,
#   'محروم': 4,
#   'نموده_است': 11,
#   'مسپله': 1,
#   'زدگی': 2,
#   'پذیرش': 5,
#   'غربی': 37,
#   'تجدد': 7,
#   'پس': 106,
#   'مشروطه': 7,
#   'سه': 65,
#   'اساسی': 25,
#   'انسان': 184,
#   'طبیعت': 15,
#   'نهایت': 25,
#   'علم': 57,
#   'جدید': 64,
#   'کرده': 43,
#   'دیدگاه': 57,
#   'چالش': 42,
#   'کشیده_است': 4,
#   'خارج': 16,
#   'خط': 9,
#   'داستان': 39,
#   'کوتاهی': 7,
#   'محمود': 6,
#   'راجی': 0,
#   'نویسنده': 99,
#   'معاصر': 36,
#   'ایرانی': 109,
#   'نگاهی': 25,
#   'گذرا': 1,
#   'بدون': 45,
#   'دقت': 4,
#   'راننده': 6,
#   'مسافرش': 0,
#   'کنم': 15,
#   'هیچ': 60,
#   'خاصی': 11,
#   'توجهی': 7,
#   'ندارم': 3,
#   'قصد': 11,
#   'ماشین': 4,
#   'آدم': 18,
#   'گذرانم': 0,
#   'ولی': 28,
#   'گوشم': 0,
#   'مشاجره': 0,
#   'لفظی': 0,
#   'بین': 118,
#   'دو': 131,
#   'جلب': 10,
#   'وقتی': 25,
#   'نگاهم': 0,
#   'دوباره': 11,
#   'برمی': 16,
#   'گردد': 29,
#   'متوجه': 11,
#   'شوم': 4,
#   'شدت': 10,
#   'کنند': 158,
#   'نگاهشان': 1,
#   'سمت': 13,
#   'من': 68,
#   'دختر': 14,
#   'همراه': 29,
#   'مسافر': 1,
#   'گریه': 0,
#   'مرا': 3,
#   'پاید': 0,
#   'نزدیک': 17,
#   'پرخاش': 0,
#   'گوید': 56,
#   'غلط': 3,
#   'کنی': 2,
#   'پول': 31,
#   'نداشتی': 0,
#   'راه': 88,
#   'کشاندی': 0,
#   'آوردی': 0,
#   'خانم': 6,
#   'شدید': 2,
#   'شما': 46,
#   'فرض': 15,
#   'کن': 6,
#   'برادر': 1,
#   'پدر': 10,
#   'چرا': 48,
#   'باعث': 23,
#   'آبروی': 0,
#   'خواهرت': 0,
#   'شوی': 1,
#   'برادری': 0,
#   'خواهری': 0,
#   'کشکی': 0,
#   'اگر': 90,
#   'مسافرهایم': 0,
#   'خواهر': 1,
#   'برادرم': 0,
#   'باشند': 26,
#   'بچه': 8,
#   'هایم': 4,
#   'گرسنگی': 0,
#   'میرند': 1,
#   'حالا': 7,
#   'هزارتا': 0,
#   'ادا': 0,
#   'آورد': 41,
#   'تو': 10,
#   'بیا': 0,
#   'کرایه': 0,
#   'برابر': 28,
#   'بده': 1,
#   'همدیگر': 1,
#   'خطاب': 1,
#   'نگاه': 32,
#   'شان': 43,
#   'دارند': 91,
#   'حرف': 12,
#   'زنند': 5,
#   'شاید': 33,
#   'خواهند_که': 0,
#   'مداخله': 10,
#   'دعوا': 1,
#   'تمام': 57,
#   'فکرم': 0,
#   'کاملا': 9,
#   'رو': 55,
#   'حاجی': 0,
#   'آقا': 0,
#   'بگویید': 0,
#   'قبل': 21,
#   'بپرسم': 0,
#   'بگویم': 4,
#   'علت': 22,
#   'توضیح': 30,
#   'او': 249,
#   'خواهد_که': 0,
#   'اش': 43,
#   'صرف': 12,
#   'پرسم': 0,
#   'قدر': 3,
#   'لاک': 2,
#   'صورتی': 0,
#   'جلال': 1,
#   'آل': 5,
#   'فعال': 10,
#   'مطالعه': 78,
#   'اضافه': 4,
#   'زیادی': 22,
#   'سرمایه': 60,
#   'گذاری': 13,
#   'دنیا': 41,
#   'ما': 247,
#   'دوره': 49,
#   'خارق': 2,
#   'العاده': 10,
#   'تاریخ': 120,
#   'بشر': 24,
#   'هزاران': 4,
#   'زمینه': 98,
#   'فراهم': 28,
#   'بسیاری': 75,
#   'سردرگم': 1,
#   'کننده': 24,
#   'فهم': 25,
#   'دشوار': 4,
#   'مارک': 2,
#   'ویکتو': 0,
#   'ر': 0,
#   'هانسن': 0,
#   'صوتی': 7,
#   'راهبردهای': 7,
#   'کسب': 19,
#   'وکار': 2,
#   'نخستین': 30,
#   'پایه': 14,
#   'ترین': 117,
#   'ابزار': 10,
#   'رشد': 53,
#   'ثروت': 6,
#   'حجم': 9,
#   'مقداری': 0,
#   'بیش': 56,
#   'اکنون': 18,
#   'افزایش': 30,
#   'دهید': 1,
#   'زیباترین': 1,
#   'وجوه': 2,
#   'تجارت': 6,
#   'تماما': 1,
#   'اساس': 36,
#   'افراد': 70,
#   'اجرا': 9,
#   'شکل': 71,
#   'روز': 49,
#   'افزون': 3,
#   'دهکده': 0,
#   'جهانی': 110,
#   'زمانی': 27,
#   'نوع': 29,
#   'بیگانه': 7,
#   'ریشه': 27,
#   'مشکلات': 18,
#   'منازعات': 2,
#   'نبود': 9,
#   'صحیح': 12,
#   'یکدیگر': 22,
#   'شناخت': 57,
#   'ناقص': 1,
#   'مشترک': 12,
#   'جوامع': 44,
#   'باز': 23,
#   'گفتمان': 61,
#   'نظرات': 8,
#   'رسانه': 293,
#   'بریتانیا': 8,
#   'چهره': 10,
#   'آیینه': 2,
#   'مطبوعات': 9,
#   'توسط': 28,
#   'آقایان': 0,
#   'پل': 5,
#   'بیکر': 0,
#   'کاستاس': 0,
#   'گابریلاتوس': 0,
#   'تونی': 1,
#   'مک': 10,
#   'انری': 0,
#   'نوشته_شده_است': 17,
#   'بهر': 0,
#   'ازپژوهش': 0,
#   'رایزنی': 0,
#   'جمهوری': 14,
#   'نظران': 10,
#   'بزرگان': 1,
#   'صاحب': 16,
#   'حوزه': 121,
#   'آگاهی': 26,
#   'خوانندگان': 17,
#   'موثر': 15,
#   'مفید': 27,
#   'واقع': 39,
#   'اختلالات': 2,
#   'مصرف': 35,
#   'مواد': 9,
#   'مشاوره': 12,
#   'اعتیاد': 15,
#   'فورد': 2,
#   'بروکس': 4,
#   'بیل': 3,
#   'ام': 11,
#   'سی': 15,
#   'هنری': 28,
#   'کتابی': 76,
#   'آخرین': 9,
#   'روش': 99,
#   'ترک': 9,
#   'موادمخدر': 1,
#   'الکل': 2,
#   'آشنا': 37,
#   'نهایی': 9,
#   'نگارش': 22,
#   'رفتارهای': 15,
#   'مشکل': 14,
#   'ساز': 15,
#   'اعتیادآور': 3,
#   'تغییر': 66,
#   'سازگارانه': 1,
#   'آموخته_شود': 1,
#   'پروفسور': 7,
#   'دانشکده': 4,
#   'کارمند': 2,
#   'دانشگاه': 96,
#   'شیپنزبورگ': 1,
#   'پنسیلوانیا': 2,
#   'ایشان': 12,
#   'برنامه': 71,
#   'بهداشت': 2,
#   'روانی': 10,
#   'بالینی': 1,
#   'همچنین': 62,
#   'عملی': 21,
#   'کارآموزی': 1,
#   'تخصصی': 21,
#   'دپارتمان': 4,
#   'ریزی': 26,
#   'سرپرستی': 4,
#   'سرویس': 3,
#   'آموزشی': 59,
#   'درمان': 20,
#   'جویان': 5,
#   'درکمپ': 1,
#   'آژانس': 2,
#   'مدارس': 6,
#   'منطقه': 25,
#   'جنوب': 5,
#   'مرکزی': 9,
#   'ارائه': 63,
#   'داد': 30,
#   'دکترای': 3,
#   'رشته': 93,
#   'ویلیام': 8,
#   'ماری': 1,
#   'فوق': 18,
#   'لیسانس': 5,
#   'ویرجینیا': 2,
#   'گرایش': 22,
#   'روان': 76,
#   'ریچموند': 1,
#   'دریافت': 20,
#   'کرده_است': 96,
#   'رئیس': 11,
#   'تحصیلات': 10,
#   'تکمیلی': 2,
#   'پژوهشی': 53,
#   'تگزاس': 1,
#   'آموزش': 78,
#   'داکوتای': 1,
#   'جنوبی': 5,
#   'مدت': 8,
#   'سال': 154,
#   'مشاور': 1,
#   'بوده_است': 48,
#   'تجربه': 39,
#   'گروهی': 18,
#   'زوجی': 1,
#   'خانوادگی': 17,
#   'سوء': 4,
#   'دانشگاهها': 1,
#   'سلامتی': 5,
#   'مراکز': 15,
#   'جست': 9,
#   'وجوی': 3,
#   'معنا': 24,
#   'رهیافتی': 1,
#   'معناشناختی': 1,
#   'اطلاعات': 55,
#   'نرگس': 3,
#   'نشاط': 1,
#   'امروزه': 36,
#   'هرکس': 3,
#   'محتوا': 19,
#   'متن': 27,
#   'سروکار': 4,
#   'نیازمند': 12,
#   'ابزاری': 9,
#   'علمی': 85,
#   'بتواند': 13,
#   'پیام': 31,
#   'مخابره': 1,
#   'انتقالی': 2,
#   'داشته_باشد': 18,
#   'سوال': 13,
#   'پرسیده_شود': 2,
#   'احساس': 24,
#   'نیاز': 47,
#   'بوجود': 3,
#   'سبب': 17,
#   'تشدید': 1,
#   'پیامی': 2,
#   'ارسال': 3,
#   'نهفته': 6,
#   'باید': 108,
#   'موضوعی': 24,
#   'برخورد': 27,
#   'معناشناسی': 1,
#   'گونه': 59,
#   'مورد': 128,
#   'پی': 26,
#   'کشف': 18,
#   'چگونگی': 53,
#   'سازماندهی': 10,
#   'بررسی': 229,
#   'تاثیر': 34,
#   'معنایی': 7,
#   'گیرنده': 5,
#   'خواننده': 25,
#   'شنونده': 5,
#   'دانست': 14,
#   'کجا': 4,
#   'سپس': 27,
#   'بازتولید': 7,
#   'تفسیر': 11,
#   'فهمیده': 1,
#   'بنابراین': 33,
#   'مساله': 8,
#   'محوری': 4,
#   'معناست': 3,
#   'مستقیم': 15,
#   'غیرمستقیم': 6,
#   'پیوند': 16,
#   'جستجوی': 7,
#   'امکانات': 6,
#   'تحقق': 9,
#   'پیوستگی': 5,
#   'ماهیت': 23,
#   'آزمایش': 5,
#   'اعتبار': 7,
#   'دانیم': 5,
#   'آیا': 40,
#   'مفهوم': 63,
#   'رها': 7,
#   'یعنی': 64,
#   'بدانیم': 7,
#   'آنجا': 16,
#   'خواهیم_معنا': 1,
#   'قیمتی': 1,
#   'قیمت': 5,
#   'خواهدشد': 2,
#   'مبارزه': 9,
#   'راهبرد': 2,
#   'آغاز': 39,
#   'اندوه': 4,
#   'بالابان': 0,
#   'رجبی': 0,
#   'مناسب': 18,
#   'گروه': 53,
#   'سنی': 3,
#   'اولین': 27,
#   'جشنواره': 0,
#   'سپیدار': 0,
#   'برگزیده': 8,
#   'انتخاب': 39,
#   'قاچاق': 0,
#   'غیر': 22,
#   'قانونی': 9,
#   'پرندگان': 1,
#   'ارزشمندی': 3,
#   'کشورهای': 43,
#   'حاشیه': 5,
#   'خلیج': 0,
#   'فارس': 2,
#   'مندو': 0,
#   'پسری': 0,
#   'نوجوان': 8,
#   'لنجی': 0,
#   'نام': 83,
#   'شبوت': 0,
#   'ناخدا': 0,
#   'سمیر': 2,
#   'کار': 121,
#   'روزهایی': 0,
#   'شارجه': 0,
#   'بروند': 4,
#   'مسافری': 0,
#   'غریبه': 3,
#   'جعبه': 0,
#   'مرموز': 0,
#   'همسفر': 0,
#   'تعدادی': 7,
#   'پرنده': 0,
#   'داخل': 4,
#   'زندانی': 1,
#   'دلش': 1,
#   'خواهد_پرنده': 0,
#   'نجات': 5,
#   'همکاری': 12,
#   'کردن': 53,
#   'همکاران': 0,
#   'دیگرش': 1,
#   'مرد': 18,
#   'خشمگین': 0,
#   'اما': 151,
#   'آخر': 12,
#   'ماموران': 1,
#   'گشت': 1,
#   'دریایی': 1,
#   'خبر': 24,
#   'قاچاقچی': 0,
#   'بگیرند': 5,
#   'دهند': 62,
#   'زیبا': 2,
#   'اصطلاحات': 7,
#   'کلمات': 2,
#   'بومی': 25,
#   'خوبی': 14,
#   'جغرافیای': 12,
#   'مهرتابناک': 0,
#   'جلد': 32,
#   'اول': 70,
#   'شمه': 0,
#   'احوالات': 0,
#   'آیت': 5,
#   'الله': 13,
#   'حاج': 3,
#   'سیدعلی': 0,
#   'قاضی': 1,
#   'آثار': 63,
#   'علامه': 3,
#   'محمدحسین': 0,
#   'حسینی': 5,
#   'طهرانی': 0,
#   'اضافاتی': 0,
#   'سیدمحمدمحسن': 0,
#   'تهرانی': 0,
#   'مدیریت': 68,
#   'خدمات': 4,
#   'مشتری': 0,
#   'ژاک': 4,
#   'هاروویتز': 0,
#   'استاد': 47,
#   'بازاریابی': 2,
#   'الملل': 4,
#   'لوزان': 0,
#   'سوییس': 0,
#   'تخصص': 4,
#   'وی': 32,
#   'ارتقای': 9,
#   'رضایت': 6,
#   'برارائه': 0,
#   'تفکیک': 5,
#   'تقویت': 8,
#   'وفاداری': 4,
#   'نتیجه': 36,
#   'خدماتی': 2,
#   'مدرسه': 13,
#   'عالی': 11,
#   'بازرگانی': 5,
#   'پاریس': 6,
#   'فرانسه': 24,
#   'فارغ': 5,
#   'التحصیل': 1,
#   'شد': 112,
#   'دکترا': 2,
#   'کلمبیا': 1,
#   'نیویورک': 9,
#   'پاداش': 1,
#   'تحصیلی': 7,
#   'شامل': 44,
#   'هزینه': 7,
#   'ساموئل': 0,
#   'بردنفمن': 0,
#   'کلی': 30,
#   'آموزشگاه': 1,
#   'امریکا': 20,
#   'فکر': 39,
#   'توسعه': 87,
#   'فعالیت': 43,
#   'مجال': 2,
#   'اندیشیدن': 7,
#   'مزایای': 2,
#   'طولی': 0,
#   'اضافی': 0,
#   'دستگاه': 7,
#   'بخرید': 0,
#   'کارش': 5,
#   'محصولاتی': 0,
#   'معین': 1,
#   'مشتریانی': 0,
#   'فروشنده': 1,
#   'فروش': 2,
#   'تواند': 80,
#   'پیشنهادش': 0,
#   'قراردادهای': 1,
#   'مربوط': 42,
#   'تعمیرات': 0,
#   'احتیاطی': 0,
#   'مستمر': 1,
#   'مشتریان': 1,
#   'درنهایت': 4,
#   'محصولات': 1,
#   'تولیدشده': 0,
#   'وسیله': 9,
#   'رأیت': 0,
#   'دین': 63,
#   'تألیف': 5,
#   'اکبر': 2,
#   'عالمیان': 0,
#   'رفتار': 31,
#   'العظمی': 1,
#   'بروجردی': 1,
#   'تحریر': 7,
#   'درآمده': 6,
#   'بخش': 136,
#   'ابتدا': 25,
#   'مرجع': 1,
#   'عظیم': 2,
#   'القدر': 0,
#   'تولد': 7,
#   'رحلت': 0,
#   'دوم': 74,
#   'رابطه': 50,
#   'مقوله': 17,
#   'محقق': 6,
#   'سوم': 50,
#   'رهبری': 10,
#   'امت': 0,
#   ...},
#  'کلیات اسلام': {'total': 65265,
#   'ساختار': 2,
#   'نظریه': 17,
#   'های': 612,
#   'جامعه': 72,
#   'شناسی': 44,
#   'ایران': 34,
#   'نوشته': 110,
#   'ابوالفضل': 2,
#   'رمضانی': 0,
#   'دربردارنده': 6,
#   'درباره': 154,
#   'از': 1736,
#   'منظر': 33,
#   'اندیشمندانی': 0,
#   'همچون': 29,
#   'جواد': 4,
#   'طباطبایی': 9,
#   'همایون': 1,
#   'کاتوزیان': 0,
#   'احمد': 18,
#   'اشرف': 1,
#   'پرویز': 0,
#   'پیران': 0,
#   'حسین': 84,
#   'بشیریه': 0,
#   'و': 4619,
#   'است': 1006,
#   'در': 2162,
#   'بخشی': 69,
#   'کتاب': 598,
#   'می': 1045,
#   'خوانیم': 36,
#   'تحلیل': 29,
#   'تاکید': 4,
#   'بیشتر': 32,
#   'بر': 340,
#   'خلاصه': 11,
#   'سازی': 17,
#   'دقیق': 10,
#   'ها': 342,
#   'با': 700,
#   'شکافتن': 0,
#   'اجزا': 0,
#   'عناصر': 5,
#   'آنها': 67,
#   'تلاش': 26,
#   'شود': 156,
#   'تا': 202,
#   'جایی': 5,
#   'که': 1166,
#   'امکان': 11,
#   'دارد': 165,
#   'کمترین': 3,
#   'چیزی': 11,
#   'قلم': 93,
#   'نیفتد': 1,
#   'هدف': 42,
#   'این': 985,
#   'برای': 333,
#   'تجزیه': 0,
#   'شناختی': 8,
#   'موجود': 19,
#   'به': 1796,
#   'اصلی': 34,
#   'منظور': 11,
#   'کمک': 11,
#   'تحقیقات': 6,
#   'تجربی': 0,
#   'آزمون': 5,
#   'همین': 48,
#   'اینها': 6,
#   'رویکردهایی': 0,
#   'نسبت': 21,
#   'خود': 213,
#   'هستند': 32,
#   'حاضر': 45,
#   'تحقیق': 22,
#   'پذیری': 6,
#   'را': 936,
#   'تسهیل': 1,
#   'کند': 155,
#   'علاوه': 17,
#   'شفاف': 1,
#   'کنار': 23,
#   'هم': 113,
#   'قرار': 120,
#   'دادن': 13,
#   'ویژگی': 36,
#   'بنیادی': 3,
#   'حاکم': 6,
#   'روابط': 6,
#   'اجتماعی': 50,
#   'دست': 71,
#   'یابیم': 0,
#   'تنها': 28,
#   'صورت': 57,
#   'توانیم': 4,
#   'اندیشه': 35,
#   'سطحی': 2,
#   'رهایی': 3,
#   'پیدا': 13,
#   'کنیم': 35,
#   'دانش': 22,
#   'تولید': 19,
#   'شده': 127,
#   'اصلاح': 10,
#   'امور': 10,
#   'استفاده': 49,
#   'نشان': 17,
#   'اجازه': 2,
#   'دهد': 67,
#   'خودش': 3,
#   'سخن': 50,
#   'بگوید': 1,
#   'دلیل': 17,
#   'نیازی': 4,
#   'نقد': 26,
#   'تحلیلی': 7,
#   'ندیدم': 0,
#   'هر': 150,
#   'چند': 28,
#   'قلت': 2,
#   'کارهای': 6,
#   'تحقیقی': 1,
#   'روی': 38,
#   'انتقادی': 3,
#   'نیز': 119,
#   'وجود': 70,
#   'ندارد': 15,
#   'بی': 68,
#   'مایه': 6,
#   'نادیده': 1,
#   'گرفتن': 8,
#   'پیشین': 2,
#   'کمکی': 0,
#   'پیشبرد': 1,
#   'پردازی': 0,
#   'نمی': 88,
#   'فرهنگ': 35,
#   'کانادا': 0,
#   'مجموعه': 188,
#   'کشورها': 0,
#   'ی': 211,
#   'نشر': 20,
#   'الهدی': 0,
#   'معرفی': 34,
#   'کشور': 10,
#   'مردم': 69,
#   'سازمان': 1,
#   'هاو': 0,
#   'نهادهای': 4,
#   'سیاسی': 36,
#   'فرهنگی': 43,
#   'پردازد': 75,
#   'پرسش': 32,
#   'مختلفی': 6,
#   'زندگی': 143,
#   'شخصیت': 26,
#   'امام': 320,
#   'مهدی': 50,
#   'عج': 44,
#   'اذهان': 6,
#   'هایی': 106,
#   'گاه': 12,
#   'میان': 60,
#   'آموزان': 4,
#   'دانشجویان': 21,
#   'دیگر': 109,
#   'اقشار': 2,
#   'مطرح': 67,
#   'دغدغه': 9,
#   'ذهنی': 7,
#   'تبدیل': 8,
#   'توجه': 46,
#   'فراوانی': 7,
#   'کسانی': 22,
#   'مجالس': 12,
#   'محافل': 3,
#   'مختلف': 57,
#   'طرح': 11,
#   'پردازند': 3,
#   'موعود': 18,
#   'ابراهیم': 19,
#   'شفیعی': 13,
#   'سروستانی': 14,
#   'چهارده': 23,
#   'مهدویت': 34,
#   'پاسخ': 56,
#   'فلسفه': 26,
#   'غیبت': 46,
#   'صغری': 2,
#   'جزیره': 2,
#   'خضرا': 1,
#   'یاران': 8,
#   'دوران': 31,
#   'وقت': 14,
#   'ظهور': 52,
#   'فتنه': 5,
#   'دجال': 7,
#   'خروج': 12,
#   'روایات': 45,
#   'متعددی': 4,
#   'گریزناپذیر': 2,
#   'بودن': 31,
#   'عنوان': 89,
#   'یکی': 81,
#   'رویدادهای': 2,
#   'آخرالزمان': 6,
#   'یا': 111,
#   'نشانه': 20,
#   'قیامت': 24,
#   'تأکید': 7,
#   'شده_است': 168,
#   'جمله': 27,
#   'روایتی': 5,
#   'امیرمؤمنان': 10,
#   'علی': 191,
#   'ع': 227,
#   'پیامبر': 68,
#   'گرامی': 10,
#   'اسلام': 142,
#   'ص': 61,
#   'نقل': 17,
#   'پیش': 46,
#   'ساعت': 1,
#   'ده': 29,
#   'رویداد': 3,
#   'سفیانی': 2,
#   'برخی': 64,
#   'حتمی': 3,
#   'مانند': 17,
#   'دانسته': 7,
#   'انکار': 5,
#   'آن': 603,
#   'کفر': 5,
#   'شمار': 16,
#   'آمده_است': 36,
#   'توان': 36,
#   'روایت': 43,
#   'نبوی': 6,
#   'زیر': 30,
#   'اشاره': 26,
#   'کرد': 69,
#   'کس': 16,
#   'منکر': 8,
#   'آنچه': 37,
#   'محمد': 90,
#   'نازل': 9,
#   'گشته': 1,
#   'کافر': 6,
#   'نزول': 8,
#   'عیسی': 6,
#   'موج': 1,
#   'دریا': 1,
#   'مهری': 0,
#   'ماهوتی': 0,
#   'تصویرگری': 1,
#   'عاطفه': 0,
#   'ملکی': 4,
#   'جو': 1,
#   'داستانی': 4,
#   'مصور': 6,
#   'کودکان': 11,
#   'جلدی': 13,
#   'چه': 97,
#   'مهربان': 4,
#   'خدا': 98,
#   'غرب': 6,
#   'دکتر': 31,
#   'اسماعیل': 13,
#   'نوعی': 4,
#   'تفاوت': 12,
#   'هستی': 41,
#   'شناسانه': 1,
#   'جهان': 52,
#   'بینی': 28,
#   'شرق': 1,
#   'مقدمه': 51,
#   'چنین': 32,
#   'خوانید': 33,
#   'اساسا': 1,
#   'پرسشی': 1,
#   'فلسفی': 10,
#   'مقام': 31,
#   'نظر': 47,
#   'ناظر': 4,
#   'درک': 17,
#   'شرایط': 21,
#   'تاریخی': 32,
#   'ویژه': 42,
#   'ای': 259,
#   'گذار': 1,
#   'ممکن': 12,
#   'نیست': 56,
#   'نقاط': 4,
#   'عطف': 5,
#   'مهم': 56,
#   'اقوام': 5,
#   'آید': 23,
#   'گویی': 14,
#   'بدان': 10,
#   'عهدۀ': 0,
#   'عوام': 7,
#   'وظیفۀ': 1,
#   'دانشمندان': 3,
#   'اربابان': 0,
#   'فن': 0,
#   'حتی': 27,
#   'سیاست': 14,
#   'مداران': 1,
#   'بلکه': 29,
#   'متفکران': 2,
#   'صاحبان': 1,
#   'آنان': 70,
#   'مخاطب': 13,
#   'پرسشند': 0,
#   'شرط': 3,
#   'آنکه': 13,
#   'رأیشان': 0,
#   'منشأ': 1,
#   'اثر': 111,
#   'باشد': 79,
#   'جهت': 33,
#   'گیری': 16,
#   'بزرگ': 39,
#   'همه': 80,
#   'چیز': 9,
#   'تمدن': 5,
#   'مناسبات': 2,
#   'معلوم': 3,
#   'سازد': 15,
#   'سرنوشت': 8,
#   'یک': 143,
#   'قوم': 10,
#   'رقم': 3,
#   'زند': 5,
#   'مسیر': 23,
#   'طی': 18,
#   'طریق': 6,
#   'نماید': 25,
#   'چگونه': 16,
#   'عرصۀ': 3,
#   'حیات': 41,
#   'روشن': 22,
#   'نگارنده': 8,
#   'ضمن': 9,
#   'ضرورت': 14,
#   'سعی': 25,
#   'بیان': 74,
#   'جایگاه': 38,
#   'موضوع': 81,
#   'کلیۀ': 0,
#   'ساکنان': 3,
#   'مشرق': 2,
#   'زمین': 21,
#   'اسلامی': 181,
#   'شیعی': 15,
#   'مذهب': 22,
#   'شایسته': 3,
#   'تر': 47,
#   'امر': 19,
#   'شناسد': 2,
#   'زیرا': 16,
#   'سایر': 11,
#   'ملل': 1,
#   'شرقی': 5,
#   'چین': 0,
#   'هند': 1,
#   'ژاپن': 0,
#   'رویارویی': 4,
#   'متحمل': 1,
#   'خسارات': 0,
#   'بسیار': 26,
#   'شده_اند': 24,
#   'لیکن': 1,
#   'حسب': 0,
#   'سابقه': 1,
#   'جان': 20,
#   'مایۀ': 2,
#   'فرهنگیشان': 0,
#   'تجدید': 8,
#   'برخوردار': 14,
#   'نیستند': 2,
#   'نظام': 39,
#   'فکری': 16,
#   'نظری': 9,
#   'فاقد': 0,
#   'رویکردی': 2,
#   'بنیادین': 0,
#   'جدی': 8,
#   'آینده': 12,
#   'اند': 29,
#   'عموم': 11,
#   'منسوخ': 0,
#   'ممسوخ': 0,
#   'آسیایی': 1,
#   'دربارۀ': 6,
#   'کیفیت': 15,
#   'برکشیدن': 0,
#   'بنای': 1,
#   'تمدنی': 5,
#   'تنظیم': 18,
#   'معاملات': 3,
#   'فردی': 19,
#   'جمعی': 2,
#   'مبنای': 5,
#   'زیرساخت': 1,
#   'ساکتند': 0,
#   'توانایی': 7,
#   'ایجاد': 19,
#   'جریان': 10,
#   'نقطه': 11,
#   'محروم': 1,
#   'نموده_است': 11,
#   'مسپله': 0,
#   'زدگی': 7,
#   'پذیرش': 6,
#   'غربی': 11,
#   'تجدد': 0,
#   'پس': 117,
#   'مشروطه': 7,
#   'سه': 55,
#   'اساسی': 21,
#   'انسان': 171,
#   'طبیعت': 6,
#   'نهایت': 15,
#   'علم': 57,
#   'جدید': 17,
#   'کرده': 31,
#   'دیدگاه': 40,
#   'چالش': 3,
#   'کشیده_است': 1,
#   'خارج': 8,
#   'خط': 9,
#   'داستان': 16,
#   'کوتاهی': 4,
#   'محمود': 8,
#   'راجی': 0,
#   'نویسنده': 32,
#   'معاصر': 21,
#   'ایرانی': 16,
#   'نگاهی': 17,
#   'گذرا': 1,
#   'بدون': 22,
#   'دقت': 11,
#   'راننده': 0,
#   'مسافرش': 0,
#   'کنم': 15,
#   'هیچ': 24,
#   'خاصی': 8,
#   'توجهی': 2,
#   'ندارم': 1,
#   'قصد': 2,
#   'ماشین': 2,
#   'آدم': 15,
#   'گذرانم': 0,
#   'ولی': 47,
#   'گوشم': 1,
#   'مشاجره': 0,
#   'لفظی': 2,
#   'بین': 49,
#   'دو': 96,
#   'جلب': 4,
#   'وقتی': 18,
#   'نگاهم': 0,
#   'دوباره': 4,
#   'برمی': 10,
#   'گردد': 52,
#   'متوجه': 3,
#   'شوم': 3,
#   'شدت': 3,
#   'کنند': 59,
#   'نگاهشان': 0,
#   'سمت': 12,
#   'من': 100,
#   'دختر': 4,
#   'همراه': 33,
#   'مسافر': 1,
#   'گریه': 7,
#   'مرا': 18,
#   'پاید': 0,
#   'نزدیک': 10,
#   'پرخاش': 0,
#   'گوید': 28,
#   'غلط': 0,
#   'کنی': 9,
#   'پول': 6,
#   'نداشتی': 0,
#   'راه': 49,
#   'کشاندی': 0,
#   'آوردی': 1,
#   'خانم': 1,
#   'شدید': 3,
#   'شما': 52,
#   'فرض': 3,
#   'کن': 16,
#   'برادر': 4,
#   'پدر': 12,
#   'چرا': 32,
#   'باعث': 13,
#   'آبروی': 0,
#   'خواهرت': 0,
#   'شوی': 1,
#   'برادری': 0,
#   'خواهری': 0,
#   'کشکی': 0,
#   'اگر': 61,
#   'مسافرهایم': 0,
#   'خواهر': 1,
#   'برادرم': 0,
#   'باشند': 13,
#   'بچه': 2,
#   'هایم': 0,
#   'گرسنگی': 0,
#   'میرند': 2,
#   'حالا': 2,
#   'هزارتا': 0,
#   'ادا': 1,
#   'آورد': 14,
#   'تو': 81,
#   'بیا': 1,
#   'کرایه': 0,
#   'برابر': 16,
#   'بده': 5,
#   'همدیگر': 0,
#   'خطاب': 6,
#   'نگاه': 39,
#   'شان': 12,
#   'دارند': 46,
#   'حرف': 9,
#   'زنند': 0,
#   'شاید': 8,
#   'خواهند_که': 0,
#   'مداخله': 0,
#   'دعوا': 0,
#   'تمام': 27,
#   'فکرم': 0,
#   'کاملا': 1,
#   'رو': 28,
#   'حاجی': 5,
#   'آقا': 5,
#   'بگویید': 0,
#   'قبل': 20,
#   'بپرسم': 0,
#   'بگویم': 0,
#   'علت': 8,
#   'توضیح': 18,
#   'او': 283,
#   'خواهد_که': 1,
#   'اش': 18,
#   'صرف': 10,
#   'پرسم': 1,
#   'قدر': 13,
#   'لاک': 0,
#   'صورتی': 1,
#   'جلال': 1,
#   'آل': 16,
#   'فعال': 2,
#   'مطالعه': 26,
#   'اضافه': 2,
#   'زیادی': 9,
#   'سرمایه': 7,
#   'گذاری': 16,
#   'دنیا': 52,
#   'ما': 131,
#   'دوره': 29,
#   'خارق': 0,
#   'العاده': 0,
#   'تاریخ': 67,
#   'بشر': 47,
#   'هزاران': 1,
#   'زمینه': 42,
#   'فراهم': 28,
#   'بسیاری': 31,
#   'سردرگم': 0,
#   'کننده': 9,
#   'فهم': 21,
#   'دشوار': 3,
#   'مارک': 1,
#   'ویکتو': 0,
#   'ر': 0,
#   'هانسن': 0,
#   'صوتی': 25,
#   'راهبردهای': 2,
#   'کسب': 8,
#   'وکار': 0,
#   'نخستین': 22,
#   'پایه': 13,
#   'ترین': 58,
#   'ابزار': 3,
#   'رشد': 20,
#   'ثروت': 1,
#   'حجم': 1,
#   'مقداری': 0,
#   'بیش': 19,
#   'اکنون': 7,
#   'افزایش': 3,
#   'دهید': 1,
#   'زیباترین': 3,
#   'وجوه': 0,
#   'تجارت': 5,
#   'تماما': 0,
#   'اساس': 39,
#   'افراد': 18,
#   'اجرا': 2,
#   'شکل': 24,
#   'روز': 46,
#   'افزون': 5,
#   'دهکده': 1,
#   'جهانی': 10,
#   'زمانی': 16,
#   'نوع': 19,
#   'بیگانه': 3,
#   'ریشه': 14,
#   'مشکلات': 14,
#   'منازعات': 2,
#   'نبود': 14,
#   'صحیح': 11,
#   'یکدیگر': 5,
#   'شناخت': 38,
#   'ناقص': 2,
#   'مشترک': 7,
#   'جوامع': 6,
#   'باز': 13,
#   'گفتمان': 7,
#   'نظرات': 2,
#   'رسانه': 5,
#   'بریتانیا': 1,
#   'چهره': 15,
#   'آیینه': 4,
#   'مطبوعات': 1,
#   'توسط': 35,
#   'آقایان': 1,
#   'پل': 3,
#   'بیکر': 1,
#   'کاستاس': 1,
#   'گابریلاتوس': 1,
#   'تونی': 1,
#   'مک': 1,
#   'انری': 1,
#   'نوشته_شده_است': 8,
#   'بهر': 1,
#   'ازپژوهش': 1,
#   'رایزنی': 1,
#   'جمهوری': 14,
#   'نظران': 6,
#   'بزرگان': 13,
#   'صاحب': 23,
#   'حوزه': 80,
#   'آگاهی': 12,
#   'خوانندگان': 8,
#   'موثر': 1,
#   'مفید': 15,
#   'واقع': 28,
#   'اختلالات': 0,
#   'مصرف': 3,
#   'مواد': 1,
#   'مشاوره': 0,
#   'اعتیاد': 0,
#   'فورد': 0,
#   'بروکس': 0,
#   'بیل': 0,
#   'ام': 13,
#   'سی': 14,
#   'هنری': 9,
#   'کتابی': 51,
#   'آخرین': 18,
#   'روش': 56,
#   'ترک': 6,
#   'موادمخدر': 0,
#   'الکل': 2,
#   'آشنا': 16,
#   'نهایی': 5,
#   'نگارش': 24,
#   'رفتارهای': 9,
#   'مشکل': 7,
#   'ساز': 14,
#   'اعتیادآور': 0,
#   'تغییر': 5,
#   'سازگارانه': 0,
#   'آموخته_شود': 0,
#   'پروفسور': 1,
#   'دانشکده': 1,
#   'کارمند': 0,
#   'دانشگاه': 32,
#   'شیپنزبورگ': 0,
#   'پنسیلوانیا': 0,
#   'ایشان': 100,
#   'برنامه': 13,
#   'بهداشت': 1,
#   'روانی': 5,
#   'بالینی': 0,
#   'همچنین': 21,
#   'عملی': 15,
#   'کارآموزی': 0,
#   'تخصصی': 11,
#   'دپارتمان': 0,
#   'ریزی': 5,
#   'سرپرستی': 3,
#   'سرویس': 0,
#   'آموزشی': 16,
#   'درمان': 0,
#   'جویان': 2,
#   'درکمپ': 0,
#   'آژانس': 0,
#   'مدارس': 0,
#   'منطقه': 3,
#   'جنوب': 1,
#   'مرکزی': 1,
#   'ارائه': 33,
#   'داد': 20,
#   'دکترای': 0,
#   'رشته': 15,
#   'ویلیام': 0,
#   'ماری': 0,
#   'فوق': 6,
#   'لیسانس': 1,
#   'ویرجینیا': 0,
#   'گرایش': 6,
#   'روان': 19,
#   'ریچموند': 0,
#   'دریافت': 3,
#   'کرده_است': 69,
#   'رئیس': 1,
#   'تحصیلات': 9,
#   'تکمیلی': 2,
#   'پژوهشی': 7,
#   'تگزاس': 0,
#   'آموزش': 30,
#   'داکوتای': 0,
#   'جنوبی': 1,
#   'مدت': 8,
#   'سال': 117,
#   'مشاور': 0,
#   'بوده_است': 26,
#   'تجربه': 4,
#   'گروهی': 10,
#   'زوجی': 0,
#   'خانوادگی': 2,
#   'سوء': 5,
#   'دانشگاهها': 0,
#   'سلامتی': 0,
#   'مراکز': 1,
#   'جست': 9,
#   'وجوی': 4,
#   'معنا': 14,
#   'رهیافتی': 0,
#   'معناشناختی': 0,
#   'اطلاعات': 2,
#   'نرگس': 2,
#   'نشاط': 2,
#   'امروزه': 1,
#   'هرکس': 3,
#   'محتوا': 1,
#   'متن': 32,
#   'سروکار': 1,
#   'نیازمند': 3,
#   'ابزاری': 1,
#   'علمی': 34,
#   'بتواند': 4,
#   'پیام': 12,
#   'مخابره': 0,
#   'انتقالی': 0,
#   'داشته_باشد': 7,
#   'سوال': 5,
#   'پرسیده_شود': 0,
#   'احساس': 9,
#   'نیاز': 17,
#   'بوجود': 1,
#   'سبب': 14,
#   'تشدید': 1,
#   'پیامی': 0,
#   'ارسال': 0,
#   'نهفته': 1,
#   'باید': 77,
#   'موضوعی': 13,
#   'برخورد': 8,
#   'معناشناسی': 2,
#   'گونه': 34,
#   'مورد': 119,
#   'پی': 13,
#   'کشف': 6,
#   'چگونگی': 13,
#   'سازماندهی': 3,
#   'بررسی': 132,
#   'تاثیر': 3,
#   'معنایی': 5,
#   'گیرنده': 0,
#   'خواننده': 9,
#   'شنونده': 1,
#   'دانست': 10,
#   'کجا': 8,
#   'سپس': 37,
#   'بازتولید': 0,
#   'تفسیر': 59,
#   'فهمیده': 1,
#   'بنابراین': 4,
#   'مساله': 5,
#   'محوری': 10,
#   'معناست': 1,
#   'مستقیم': 3,
#   'غیرمستقیم': 1,
#   'پیوند': 13,
#   'جستجوی': 3,
#   'امکانات': 2,
#   'تحقق': 13,
#   'پیوستگی': 1,
#   'ماهیت': 5,
#   'آزمایش': 0,
#   'اعتبار': 5,
#   'دانیم': 1,
#   'آیا': 29,
#   'مفهوم': 27,
#   'رها': 4,
#   'یعنی': 48,
#   'بدانیم': 4,
#   'آنجا': 20,
#   'خواهیم_معنا': 0,
#   'قیمتی': 0,
#   'قیمت': 5,
#   'خواهدشد': 0,
#   'مبارزه': 14,
#   'راهبرد': 0,
#   'آغاز': 28,
#   'اندوه': 2,
#   'بالابان': 0,
#   'رجبی': 1,
#   'مناسب': 11,
#   'گروه': 12,
#   'سنی': 2,
#   'اولین': 15,
#   'جشنواره': 0,
#   'سپیدار': 0,
#   'برگزیده': 6,
#   'انتخاب': 25,
#   'قاچاق': 0,
#   'غیر': 16,
#   'قانونی': 0,
#   'پرندگان': 0,
#   'ارزشمندی': 3,
#   'کشورهای': 4,
#   'حاشیه': 0,
#   'خلیج': 0,
#   'فارس': 5,
#   'مندو': 0,
#   'پسری': 0,
#   'نوجوان': 1,
#   'لنجی': 0,
#   'نام': 52,
#   'شبوت': 0,
#   'ناخدا': 0,
#   'سمیر': 0,
#   'کار': 39,
#   'روزهایی': 0,
#   'شارجه': 0,
#   'بروند': 2,
#   'مسافری': 0,
#   'غریبه': 0,
#   'جعبه': 0,
#   'مرموز': 0,
#   'همسفر': 0,
#   'تعدادی': 1,
#   'پرنده': 1,
#   'داخل': 2,
#   'زندانی': 0,
#   'دلش': 2,
#   'خواهد_پرنده': 0,
#   'نجات': 9,
#   'همکاری': 8,
#   'کردن': 24,
#   'همکاران': 0,
#   'دیگرش': 0,
#   'مرد': 11,
#   'خشمگین': 3,
#   'اما': 65,
#   'آخر': 7,
#   'ماموران': 0,
#   'گشت': 1,
#   'دریایی': 0,
#   'خبر': 15,
#   'قاچاقچی': 0,
#   'بگیرند': 5,
#   'دهند': 9,
#   'زیبا': 4,
#   'اصطلاحات': 7,
#   'کلمات': 10,
#   'بومی': 1,
#   'خوبی': 15,
#   'جغرافیای': 0,
#   'مهرتابناک': 1,
#   'جلد': 93,
#   'اول': 86,
#   'شمه': 5,
#   'احوالات': 1,
#   'آیت': 60,
#   'الله': 188,
#   'حاج': 11,
#   'سیدعلی': 5,
#   'قاضی': 10,
#   'آثار': 87,
#   'علامه': 38,
#   'محمدحسین': 9,
#   'حسینی': 48,
#   'طهرانی': 20,
#   'اضافاتی': 1,
#   'سیدمحمدمحسن': 3,
#   'تهرانی': 12,
#   'مدیریت': 9,
#   'خدمات': 1,
#   'مشتری': 0,
#   'ژاک': 0,
#   'هاروویتز': 0,
#   'استاد': 113,
#   'بازاریابی': 0,
#   'الملل': 3,
#   'لوزان': 0,
#   'سوییس': 0,
#   'تخصص': 0,
#   'وی': 30,
#   'ارتقای': 1,
#   'رضایت': 7,
#   'برارائه': 0,
#   'تفکیک': 1,
#   'تقویت': 9,
#   'وفاداری': 1,
#   'نتیجه': 16,
#   'خدماتی': 0,
#   'مدرسه': 14,
#   'عالی': 12,
#   'بازرگانی': 2,
#   'پاریس': 1,
#   'فرانسه': 2,
#   'فارغ': 0,
#   'التحصیل': 0,
#   'شد': 80,
#   'دکترا': 0,
#   'کلمبیا': 0,
#   'نیویورک': 0,
#   'پاداش': 0,
#   'تحصیلی': 2,
#   'شامل': 45,
#   'هزینه': 2,
#   'ساموئل': 0,
#   'بردنفمن': 0,
#   'کلی': 23,
#   'آموزشگاه': 0,
#   'امریکا': 1,
#   'فکر': 15,
#   'توسعه': 11,
#   'فعالیت': 9,
#   'مجال': 1,
#   'اندیشیدن': 0,
#   'مزایای': 1,
#   'طولی': 0,
#   'اضافی': 1,
#   'دستگاه': 8,
#   'بخرید': 0,
#   'کارش': 1,
#   'محصولاتی': 0,
#   'معین': 2,
#   'مشتریانی': 0,
#   'فروشنده': 0,
#   'فروش': 1,
#   'تواند': 40,
#   'پیشنهادش': 0,
#   'قراردادهای': 0,
#   'مربوط': 19,
#   'تعمیرات': 0,
#   'احتیاطی': 0,
#   'مستمر': 7,
#   'مشتریان': 0,
#   'درنهایت': 0,
#   'محصولات': 0,
#   'تولیدشده': 0,
#   'وسیله': 11,
#   'رأیت': 1,
#   'دین': 99,
#   'تألیف': 15,
#   'اکبر': 6,
#   'عالمیان': 1,
#   'رفتار': 15,
#   'العظمی': 11,
#   'بروجردی': 6,
#   'تحریر': 3,
#   'درآمده': 7,
#   'بخش': 124,
#   'ابتدا': 30,
#   'مرجع': 5,
#   'عظیم': 6,
#   'القدر': 4,
#   'تولد': 7,
#   'رحلت': 6,
#   'دوم': 72,
#   'رابطه': 30,
#   'مقوله': 10,
#   'محقق': 8,
#   'سوم': 35,
#   'رهبری': 18,
#   'امت': 24,
#   ...},
#  'داستان کودک و نوجوانان': {'total': 40765,
#   'ساختار': 0,
#   'نظریه': 1,
#   'های': 595,
#   'جامعه': 4,
#   'شناسی': 0,
#   'ایران': 21,
#   'نوشته': 155,
#   'ابوالفضل': 2,
#   'رمضانی': 6,
#   'دربردارنده': 6,
#   'درباره': 75,
#   'از': 976,
#   'منظر': 0,
#   'اندیشمندانی': 0,
#   'همچون': 8,
#   'جواد': 2,
#   'طباطبایی': 1,
#   'همایون': 0,
#   'کاتوزیان': 0,
#   'احمد': 6,
#   'اشرف': 0,
#   'پرویز': 1,
#   'پیران': 0,
#   'حسین': 13,
#   'بشیریه': 0,
#   'و': 2008,
#   'است': 674,
#   'در': 818,
#   'بخشی': 38,
#   'کتاب': 439,
#   'می': 1201,
#   'خوانیم': 44,
#   'تحلیل': 1,
#   'تاکید': 0,
#   'بیشتر': 17,
#   'بر': 60,
#   'خلاصه': 5,
#   'سازی': 6,
#   'دقیق': 0,
#   'ها': 343,
#   'با': 512,
#   'شکافتن': 0,
#   'اجزا': 0,
#   'عناصر': 0,
#   'آنها': 58,
#   'تلاش': 10,
#   'شود': 133,
#   'تا': 174,
#   'جایی': 16,
#   'که': 853,
#   'امکان': 0,
#   'دارد': 101,
#   'کمترین': 1,
#   'چیزی': 21,
#   'قلم': 63,
#   'نیفتد': 0,
#   'هدف': 6,
#   'این': 586,
#   'برای': 389,
#   'تجزیه': 0,
#   'شناختی': 0,
#   'موجود': 7,
#   'به': 1157,
#   'اصلی': 5,
#   'منظور': 3,
#   'کمک': 38,
#   'تحقیقات': 0,
#   'تجربی': 0,
#   'آزمون': 0,
#   'همین': 42,
#   'اینها': 0,
#   'رویکردهایی': 0,
#   'نسبت': 5,
#   'خود': 93,
#   'هستند': 36,
#   'حاضر': 9,
#   'تحقیق': 1,
#   'پذیری': 4,
#   'را': 818,
#   'تسهیل': 0,
#   'کند': 229,
#   'علاوه': 9,
#   'شفاف': 0,
#   'کنار': 36,
#   'هم': 181,
#   'قرار': 18,
#   'دادن': 15,
#   'ویژگی': 2,
#   'بنیادی': 0,
#   'حاکم': 0,
#   'روابط': 1,
#   'اجتماعی': 3,
#   'دست': 41,
#   'یابیم': 0,
#   'تنها': 19,
#   'صورت': 30,
#   'توانیم': 7,
#   'اندیشه': 3,
#   'سطحی': 1,
#   'رهایی': 0,
#   'پیدا': 33,
#   'کنیم': 23,
#   'دانش': 4,
#   'تولید': 0,
#   'شده': 63,
#   'اصلاح': 1,
#   'امور': 0,
#   'استفاده': 18,
#   'نشان': 11,
#   'اجازه': 6,
#   'دهد': 40,
#   'خودش': 54,
#   'سخن': 2,
#   'بگوید': 6,
#   'دلیل': 8,
#   'نیازی': 3,
#   'نقد': 0,
#   'تحلیلی': 1,
#   'ندیدم': 0,
#   'هر': 103,
#   'چند': 31,
#   'قلت': 0,
#   'کارهای': 9,
#   'تحقیقی': 0,
#   'روی': 66,
#   'انتقادی': 1,
#   'نیز': 30,
#   'وجود': 28,
#   'ندارد': 13,
#   'بی': 51,
#   'مایه': 1,
#   'نادیده': 0,
#   'گرفتن': 5,
#   'پیشین': 1,
#   'کمکی': 0,
#   'پیشبرد': 0,
#   'پردازی': 1,
#   'نمی': 87,
#   'فرهنگ': 3,
#   'کانادا': 0,
#   'مجموعه': 308,
#   'کشورها': 1,
#   'ی': 274,
#   'نشر': 8,
#   'الهدی': 0,
#   'معرفی': 6,
#   'کشور': 6,
#   'مردم': 31,
#   'سازمان': 0,
#   'هاو': 0,
#   'نهادهای': 0,
#   'سیاسی': 2,
#   'فرهنگی': 3,
#   'پردازد': 22,
#   'پرسش': 0,
#   'مختلفی': 4,
#   'زندگی': 167,
#   'شخصیت': 15,
#   'امام': 23,
#   'مهدی': 11,
#   'عج': 4,
#   'اذهان': 0,
#   'هایی': 89,
#   'گاه': 6,
#   'میان': 16,
#   'آموزان': 4,
#   'دانشجویان': 0,
#   'دیگر': 70,
#   'اقشار': 0,
#   'مطرح': 2,
#   'دغدغه': 1,
#   'ذهنی': 0,
#   'تبدیل': 20,
#   'توجه': 11,
#   'فراوانی': 0,
#   'کسانی': 6,
#   'مجالس': 0,
#   'محافل': 0,
#   'مختلف': 10,
#   'طرح': 2,
#   'پردازند': 0,
#   'موعود': 0,
#   'ابراهیم': 2,
#   'شفیعی': 0,
#   'سروستانی': 0,
#   'چهارده': 4,
#   'مهدویت': 0,
#   'پاسخ': 5,
#   'فلسفه': 2,
#   'غیبت': 13,
#   'صغری': 0,
#   'جزیره': 12,
#   'خضرا': 0,
#   'یاران': 0,
#   'دوران': 9,
#   'وقت': 30,
#   'ظهور': 0,
#   'فتنه': 0,
#   'دجال': 0,
#   'خروج': 1,
#   'روایات': 13,
#   'متعددی': 2,
#   'گریزناپذیر': 0,
#   'بودن': 7,
#   'عنوان': 17,
#   'یکی': 91,
#   'رویدادهای': 2,
#   'آخرالزمان': 0,
#   'یا': 36,
#   'نشانه': 3,
#   'قیامت': 0,
#   'تأکید': 0,
#   'شده_است': 58,
#   'جمله': 9,
#   'روایتی': 4,
#   'امیرمؤمنان': 0,
#   'علی': 28,
#   'ع': 44,
#   'پیامبر': 15,
#   'گرامی': 0,
#   'اسلام': 4,
#   'ص': 11,
#   'نقل': 0,
#   'پیش': 42,
#   'ساعت': 4,
#   'ده': 18,
#   'رویداد': 0,
#   'سفیانی': 0,
#   'برخی': 7,
#   'حتمی': 0,
#   'مانند': 18,
#   'دانسته': 0,
#   'انکار': 0,
#   'آن': 243,
#   'کفر': 0,
#   'شمار': 2,
#   'آمده_است': 5,
#   'توان': 7,
#   'روایت': 49,
#   'نبوی': 0,
#   'زیر': 18,
#   'اشاره': 9,
#   'کرد': 185,
#   'کس': 12,
#   'منکر': 0,
#   'آنچه': 1,
#   'محمد': 18,
#   'نازل': 1,
#   'گشته': 0,
#   'کافر': 0,
#   'نزول': 1,
#   'عیسی': 3,
#   'موج': 3,
#   'دریا': 9,
#   'مهری': 3,
#   'ماهوتی': 3,
#   'تصویرگری': 104,
#   'عاطفه': 7,
#   'ملکی': 7,
#   'جو': 13,
#   'داستانی': 76,
#   'مصور': 22,
#   'کودکان': 231,
#   'جلدی': 30,
#   'چه': 68,
#   'مهربان': 16,
#   'خدا': 38,
#   'غرب': 0,
#   'دکتر': 10,
#   'اسماعیل': 6,
#   'نوعی': 2,
#   'تفاوت': 1,
#   'هستی': 3,
#   'شناسانه': 0,
#   'جهان': 9,
#   'بینی': 5,
#   'شرق': 2,
#   'مقدمه': 2,
#   'چنین': 7,
#   'خوانید': 8,
#   'اساسا': 0,
#   'پرسشی': 0,
#   'فلسفی': 1,
#   'مقام': 0,
#   'نظر': 18,
# ...
#   'آیت': 0,
#   'الله': 2,
#   'حاج': 0,
#   'سیدعلی': 0,
#   'قاضی': 1,
#   'آثار': 8,
#   'علامه': 0,
#   'محمدحسین': 0,
#   'حسینی': 1,
#   'طهرانی': 0,
#   'اضافاتی': 0,
#   'سیدمحمدمحسن': 0,
#   'تهرانی': 0,
#   'مدیریت': 301,
#   'خدمات': 47,
#   'مشتری': 109,
#   'ژاک': 2,
#   'هاروویتز': 3,
#   'استاد': 23,
#   'بازاریابی': 194,
#   'الملل': 6,
#   'لوزان': 1,
#   'سوییس': 1,
#   'تخصص': 6,
#   'وی': 33,
#   'ارتقای': 13,
#   'رضایت': 11,
#   'برارائه': 1,
#   'تفکیک': 3,
#   'تقویت': 22,
#   'وفاداری': 2,
#   'نتیجه': 52,
#   'خدماتی': 8,
#   'مدرسه': 11,
#   'عالی': 42,
#   'بازرگانی': 20,
#   'پاریس': 1,
#   'فرانسه': 1,
#   'فارغ': 15,
#   'التحصیل': 9,
#   'شد': 71,
#   'دکترا': 2,
#   'کلمبیا': 1,
#   'نیویورک': 17,
#   'پاداش': 5,
#   'تحصیلی': 5,
#   'شامل': 34,
#   'هزینه': 41,
#   'ساموئل': 1,
#   'بردنفمن': 1,
#   'کلی': 29,
#   'آموزشگاه': 1,
#   'امریکا': 8,
#   'فکر': 87,
#   'توسعه': 63,
#   'فعالیت': 55,
#   'مجال': 1,
#   'اندیشیدن': 5,
#   'مزایای': 11,
#   'طولی': 1,
#   'اضافی': 2,
#   'دستگاه': 6,
#   'بخرید': 2,
#   'کارش': 5,
#   'محصولاتی': 2,
#   'معین': 5,
#   'مشتریانی': 1,
#   'فروشنده': 22,
#   'فروش': 158,
#   'تواند': 104,
#   'پیشنهادش': 1,
#   'قراردادهای': 1,
#   'مربوط': 44,
#   'تعمیرات': 1,
#   'احتیاطی': 2,
#   'مستمر': 3,
#   'مشتریان': 53,
#   'درنهایت': 5,
#   'محصولات': 31,
#   'تولیدشده': 1,
#   'وسیله': 10,
#   'رأیت': 0,
#   'دین': 0,
#   'تألیف': 11,
#   'اکبر': 1,
#   'عالمیان': 0,
#   'رفتار': 76,
#   'العظمی': 0,
#   'بروجردی': 0,
#   'تحریر': 1,
#   'درآمده': 0,
#   'بخش': 117,
#   'ابتدا': 14,
#   'مرجع': 2,
#   'عظیم': 6,
#   'القدر': 0,
#   'تولد': 0,
#   'رحلت': 0,
#   'دوم': 37,
#   'رابطه': 32,
#   'مقوله': 6,
#   'محقق': 6,
#   'سوم': 21,
#   'رهبری': 124,
#   'امت': 0,
#   ...},
#  'رمان': {'total': 122779,
#   'ساختار': 5,
#   'نظریه': 3,
#   'های': 1151,
#   'جامعه': 51,
#   'شناسی': 6,
#   'ایران': 40,
#   'نوشته': 170,
#   'ابوالفضل': 0,
#   'رمضانی': 0,
#   'دربردارنده': 1,
#   'درباره': 185,
#   'از': 3189,
#   'منظر': 4,
#   'اندیشمندانی': 0,
#   'همچون': 28,
#   'جواد': 0,
#   'طباطبایی': 1,
#   'همایون': 3,
#   'کاتوزیان': 0,
#   'احمد': 24,
#   'اشرف': 4,
#   'پرویز': 3,
#   'پیران': 0,
#   'حسین': 9,
#   'بشیریه': 0,
#   'و': 5875,
#   'است': 1698,
#   'در': 3248,
#   'بخشی': 148,
#   'کتاب': 748,
#   'می': 4208,
#   'خوانیم': 118,
#   'تحلیل': 10,
#   'تاکید': 1,
#   'بیشتر': 82,
#   'بر': 282,
#   'خلاصه': 14,
#   'سازی': 7,
#   'دقیق': 20,
#   'ها': 835,
#   'با': 1484,
#   'شکافتن': 0,
#   'اجزا': 0,
#   'عناصر': 6,
#   'آنها': 157,
#   'تلاش': 46,
#   'شود': 501,
#   'تا': 477,
#   'جایی': 56,
#   'که': 3181,
#   'امکان': 12,
#   'دارد': 316,
#   'کمترین': 4,
#   'چیزی': 88,
#   'قلم': 27,
#   'نیفتد': 0,
#   'هدف': 11,
#   'این': 1714,
#   'برای': 600,
#   'تجزیه': 2,
#   'شناختی': 1,
#   'موجود': 14,
#   'به': 3489,
#   'اصلی': 79,
#   'منظور': 5,
#   'کمک': 25,
#   'تحقیقات': 6,
#   'تجربی': 0,
#   'آزمون': 0,
#   'همین': 146,
#   'اینها': 2,
#   'رویکردهایی': 0,
#   'نسبت': 26,
#   'خود': 473,
#   'هستند': 65,
#   'حاضر': 33,
#   'تحقیق': 9,
#   'پذیری': 0,
#   'را': 2635,
#   'تسهیل': 0,
#   'کند': 727,
#   'علاوه': 16,
#   'شفاف': 4,
#   'کنار': 110,
#   'هم': 611,
#   'قرار': 129,
#   'دادن': 33,
#   'ویژگی': 18,
#   'بنیادی': 0,
#   'حاکم': 10,
#   'روابط': 30,
#   'اجتماعی': 53,
#   'دست': 250,
#   'یابیم': 1,
#   'تنها': 100,
#   'صورت': 50,
#   'توانیم': 8,
#   'اندیشه': 18,
#   'سطحی': 0,
#   'رهایی': 12,
#   'پیدا': 91,
#   'کنیم': 51,
#   'دانش': 9,
#   'تولید': 1,
#   'شده': 192,
#   'اصلاح': 2,
#   'امور': 6,
#   'استفاده': 23,
#   'نشان': 79,
#   'اجازه': 18,
#   'دهد': 159,
#   'خودش': 130,
#   'سخن': 12,
#   'بگوید': 18,
#   'دلیل': 50,
#   'نیازی': 5,
#   'نقد': 9,
#   'تحلیلی': 0,
#   'ندیدم': 0,
#   'هر': 239,
#   'چند': 102,
#   'قلت': 0,
#   'کارهای': 18,
#   'تحقیقی': 0,
#   'روی': 222,
#   'انتقادی': 6,
#   'نیز': 129,
#   'وجود': 91,
#   'ندارد': 65,
#   'بی': 263,
#   'مایه': 23,
#   'نادیده': 4,
#   'گرفتن': 18,
#   'پیشین': 5,
#   'کمکی': 4,
#   'پیشبرد': 1,
#   'پردازی': 10,
#   'نمی': 414,
#   'فرهنگ': 21,
#   'کانادا': 4,
#   'مجموعه': 42,
#   'کشورها': 1,
#   'ی': 512,
#   'نشر': 7,
#   'الهدی': 0,
#   'معرفی': 18,
#   'کشور': 46,
#   'مردم': 73,
#   'سازمان': 6,
#   'هاو': 1,
#   'نهادهای': 0,
#   'سیاسی': 33,
#   'فرهنگی': 10,
#   'پردازد': 40,
#   'پرسش': 6,
#   'مختلفی': 8,
#   'زندگی': 537,
#   'شخصیت': 149,
#   'امام': 17,
#   'مهدی': 17,
#   'عج': 1,
#   'اذهان': 0,
#   'هایی': 181,
#   'گاه': 37,
#   'میان': 132,
#   'آموزان': 1,
#   'دانشجویان': 1,
#   'دیگر': 252,
#   'اقشار': 3,
#   'مطرح': 17,
#   'دغدغه': 23,
#   'ذهنی': 13,
#   'تبدیل': 29,
#   'توجه': 40,
#   'فراوانی': 8,
#   'کسانی': 47,
#   'مجالس': 1,
#   'محافل': 5,
#   'مختلف': 42,
#   'طرح': 7,
#   'پردازند': 2,
#   'موعود': 0,
#   'ابراهیم': 6,
#   'شفیعی': 1,
#   'سروستانی': 0,
#   'چهارده': 5,
#   'مهدویت': 0,
#   'پاسخ': 16,
#   'فلسفه': 8,
#   'غیبت': 1,
#   'صغری': 0,
#   'جزیره': 8,
#   'خضرا': 0,
#   'یاران': 1,
#   'دوران': 60,
#   'وقت': 76,
#   'ظهور': 5,
#   'فتنه': 3,
#   'دجال': 0,
#   'خروج': 2,
#   'روایات': 1,
#   'متعددی': 8,
#   'گریزناپذیر': 0,
#   'بودن': 30,
#   'عنوان': 87,
#   'یکی': 184,
#   'رویدادهای': 7,
#   'آخرالزمان': 1,
#   'یا': 216,
#   'نشانه': 12,
#   'قیامت': 0,
#   'تأکید': 3,
#   'شده_است': 112,
#   'جمله': 34,
#   'روایتی': 18,
#   'امیرمؤمنان': 0,
#   'علی': 43,
#   'ع': 8,
#   'پیامبر': 1,
#   'گرامی': 0,
#   'اسلام': 4,
#   'ص': 2,
#   'نقل': 16,
#   'پیش': 180,
#   'ساعت': 54,
#   'ده': 28,
#   'رویداد': 4,
#   'سفیانی': 0,
#   'برخی': 24,
#   'حتمی': 1,
#   'مانند': 81,
#   'دانسته': 5,
#   'انکار': 0,
#   'آن': 994,
#   'کفر': 1,
#   'شمار': 27,
#   'آمده_است': 16,
#   'توان': 61,
#   'روایت': 162,
#   'نبوی': 0,
#   'زیر': 74,
#   'اشاره': 30,
#   'کرد': 460,
#   'کس': 22,
#   'منکر': 1,
#   'آنچه': 37,
#   'محمد': 17,
#   'نازل': 1,
#   'گشته': 0,
#   'کافر': 1,
#   'نزول': 0,
#   'عیسی': 5,
#   'موج': 9,
#   'دریا': 34,
#   'مهری': 6,
#   'ماهوتی': 0,
#   'تصویرگری': 0,
#   'عاطفه': 2,
#   'ملکی': 2,
#   'جو': 11,
#   'داستانی': 125,
#   'مصور': 0,
#   'کودکان': 15,
#   'جلدی': 9,
#   'چه': 212,
#   'مهربان': 12,
#   'خدا': 33,
#   'غرب': 8,
#   'دکتر': 26,
#   'اسماعیل': 3,
#   'نوعی': 32,
#   'تفاوت': 10,
#   'هستی': 25,
#   'شناسانه': 3,
#   'جهان': 92,
#   'بینی': 18,
#   'شرق': 9,
#   'مقدمه': 11,
#   'چنین': 43,
#   'خوانید': 21,
#   'اساسا': 1,
#   'پرسشی': 0,
#   'فلسفی': 17,
#   'مقام': 13,
#   'نظر': 81,
#   'ناظر': 1,
#   'درک': 28,
#   'شرایط': 19,
#   'تاریخی': 54,
#   'ویژه': 24,
#   'ای': 537,
#   'گذار': 5,
#   'ممکن': 24,
#   'نیست': 139,
#   'نقاط': 3,
#   'عطف': 1,
#   'مهم': 47,
#   'اقوام': 3,
#   'آید': 54,
#   'گویی': 34,
#   'بدان': 5,
#   'عهدۀ': 0,
#   'عوام': 0,
#   'وظیفۀ': 0,
#   'دانشمندان': 0,
#   'اربابان': 0,
#   'فن': 9,
#   'حتی': 99,
#   'سیاست': 7,
#   'مداران': 0,
#   'بلکه': 36,
#   'متفکران': 0,
#   'صاحبان': 0,
#   'آنان': 19,
#   'مخاطب': 14,
#   'پرسشند': 0,
#   'شرط': 4,
#   'آنکه': 17,
#   'رأیشان': 0,
#   'منشأ': 0,
#   'اثر': 219,
#   'باشد': 96,
#   'جهت': 10,
#   'گیری': 17,
#   'بزرگ': 168,
#   'همه': 232,
#   'چیز': 79,
#   'تمدن': 5,
#   'مناسبات': 5,
#   'معلوم': 10,
#   'سازد': 17,
#   'سرنوشت': 15,
#   'یک': 806,
#   'قوم': 6,
#   'رقم': 10,
#   'زند': 51,
#   'مسیر': 19,
#   'طی': 20,
#   'طریق': 9,
#   'نماید': 3,
#   'چگونه': 20,
#   'عرصۀ': 0,
#   'حیات': 10,
#   'روشن': 41,
#   'نگارنده': 0,
#   'ضمن': 6,
#   'ضرورت': 1,
#   'سعی': 28,
#   'بیان': 49,
#   'جایگاه': 7,
#   'موضوع': 59,
#   'کلیۀ': 0,
#   'ساکنان': 9,
#   'مشرق': 3,
#   'زمین': 53,
#   'اسلامی': 4,
#   'شیعی': 0,
#   'مذهب': 5,
#   'شایسته': 3,
#   'تر': 117,
#   'امر': 9,
#   'شناسد': 9,
#   'زیرا': 23,
#   'سایر': 10,
#   'ملل': 1,
#   'شرقی': 17,
#   'چین': 8,
#   'هند': 3,
#   'ژاپن': 8,
#   'رویارویی': 6,
#   'متحمل': 2,
#   'خسارات': 0,
#   'بسیار': 80,
#   'شده_اند': 34,
#   'لیکن': 0,
#   'حسب': 0,
#   'سابقه': 4,
#   'جان': 54,
#   'مایۀ': 1,
#   'فرهنگیشان': 0,
#   'تجدید': 4,
#   'برخوردار': 3,
#   'نیستند': 10,
#   'نظام': 8,
#   'فکری': 12,
#   'نظری': 4,
#   'فاقد': 1,
#   'رویکردی': 2,
#   'بنیادین': 1,
#   'جدی': 10,
#   'آینده': 28,
#   'اند': 58,
#   'عموم': 1,
#   'منسوخ': 0,
#   'ممسوخ': 0,
#   'آسیایی': 3,
#   'دربارۀ': 4,
#   'کیفیت': 0,
#   'برکشیدن': 0,
#   'بنای': 3,
#   'تمدنی': 1,
#   'تنظیم': 0,
#   'معاملات': 2,
#   'فردی': 11,
#   'جمعی': 2,
#   'مبنای': 1,
#   'زیرساخت': 1,
#   'ساکتند': 0,
#   'توانایی': 10,
#   'ایجاد': 20,
#   'جریان': 24,
#   'نقطه': 20,
#   'محروم': 3,
#   'نموده_است': 1,
#   'مسپله': 0,
#   'زدگی': 1,
#   'پذیرش': 2,
#   'غربی': 6,
#   'تجدد': 2,
#   'پس': 200,
#   'مشروطه': 5,
#   'سه': 115,
#   'اساسی': 7,
#   'انسان': 80,
#   'طبیعت': 9,
#   'نهایت': 24,
#   'علم': 3,
#   'جدید': 22,
#   'کرده': 100,
#   'دیدگاه': 6,
#   'چالش': 11,
#   'کشیده_است': 7,
#   'خارج': 16,
#   'خط': 25,
#   'داستان': 664,
#   'کوتاهی': 18,
#   'محمود': 6,
#   'راجی': 0,
#   'نویسنده': 445,
#   'معاصر': 76,
#   'ایرانی': 77,
#   'نگاهی': 23,
#   'گذرا': 0,
#   'بدون': 59,
#   'دقت': 14,
#   'راننده': 3,
#   'مسافرش': 1,
#   'کنم': 141,
#   'هیچ': 163,
#   'خاصی': 18,
#   'توجهی': 7,
#   'ندارم': 12,
#   'قصد': 19,
#   'ماشین': 15,
#   'آدم': 103,
#   'گذرانم': 0,
#   'ولی': 106,
#   'گوشم': 6,
#   'مشاجره': 0,
#   'لفظی': 0,
#   'بین': 82,
#   'دو': 264,
#   'جلب': 10,
#   'وقتی': 122,
#   'نگاهم': 5,
#   'دوباره': 44,
#   'برمی': 45,
#   'گردد': 31,
#   'متوجه': 39,
#   'شوم': 20,
#   'شدت': 14,
#   'کنند': 186,
#   'نگاهشان': 1,
#   'سمت': 41,
#   'من': 408,
#   'دختر': 90,
#   'همراه': 78,
#   'مسافر': 6,
#   'گریه': 16,
#   'مرا': 48,
#   'پاید': 0,
#   'نزدیک': 51,
#   'پرخاش': 0,
#   'گوید': 56,
#   'غلط': 8,
#   'کنی': 51,
#   'پول': 49,
#   'نداشتی': 1,
#   'راه': 114,
#   'کشاندی': 0,
#   'آوردی': 1,
#   'خانم': 40,
#   'شدید': 5,
#   'شما': 65,
#   'فرض': 4,
#   'کن': 33,
#   'برادر': 26,
#   'پدر': 87,
#   'چرا': 48,
#   'باعث': 37,
#   'آبروی': 2,
#   'خواهرت': 0,
#   'شوی': 1,
#   'برادری': 0,
#   'خواهری': 0,
#   'کشکی': 0,
#   'اگر': 110,
#   'مسافرهایم': 0,
#   'خواهر': 21,
#   'برادرم': 5,
#   'باشند': 17,
#   'بچه': 82,
#   'هایم': 16,
#   'گرسنگی': 3,
#   'میرند': 2,
#   'حالا': 84,
#   'هزارتا': 0,
#   'ادا': 3,
#   'آورد': 57,
#   'تو': 170,
#   'بیا': 6,
#   'کرایه': 3,
#   'برابر': 23,
#   'بده': 6,
#   'همدیگر': 6,
#   'خطاب': 7,
#   'نگاه': 85,
#   'شان': 82,
#   'دارند': 62,
#   'حرف': 76,
#   'زنند': 11,
#   'شاید': 81,
#   'خواهند_که': 1,
#   'مداخله': 1,
#   'دعوا': 5,
#   'تمام': 137,
#   'فکرم': 0,
#   'کاملا': 33,
#   'رو': 160,
#   'حاجی': 1,
#   'آقا': 13,
#   'بگویید': 0,
#   'قبل': 41,
#   'بپرسم': 1,
#   'بگویم': 8,
#   'علت': 8,
#   'توضیح': 9,
#   'او': 1055,
#   'خواهد_که': 1,
#   'اش': 325,
#   'صرف': 15,
#   'پرسم': 0,
#   'قدر': 32,
#   'لاک': 0,
#   'صورتی': 12,
#   'جلال': 6,
#   'آل': 7,
#   'فعال': 6,
#   'مطالعه': 13,
#   'اضافه': 3,
#   'زیادی': 76,
#   'سرمایه': 18,
#   'گذاری': 8,
#   'دنیا': 104,
#   'ما': 182,
#   'دوره': 31,
#   'خارق': 3,
#   'العاده': 10,
#   'تاریخ': 56,
#   'بشر': 3,
#   'هزاران': 5,
#   'زمینه': 14,
#   'فراهم': 4,
#   'بسیاری': 69,
#   'سردرگم': 2,
#   'کننده': 16,
#   'فهم': 4,
#   'دشوار': 4,
#   'مارک': 10,
#   'ویکتو': 0,
#   'ر': 2,
#   'هانسن': 0,
#   'صوتی': 62,
#   'راهبردهای': 0,
#   'کسب': 11,
#   'وکار': 1,
#   'نخستین': 42,
#   'پایه': 11,
#   'ترین': 133,
#   'ابزار': 0,
#   'رشد': 11,
#   'ثروت': 14,
#   'حجم': 2,
#   'مقداری': 3,
#   'بیش': 59,
#   'اکنون': 33,
#   'افزایش': 2,
#   'دهید': 1,
#   'زیباترین': 8,
#   'وجوه': 2,
#   'تجارت': 4,
#   'تماما': 0,
#   'اساس': 30,
#   'افراد': 31,
#   'اجرا': 4,
#   'شکل': 46,
#   'روز': 156,
#   'افزون': 2,
#   'دهکده': 10,
#   'جهانی': 61,
#   'زمانی': 60,
#   'نوع': 15,
#   'بیگانه': 18,
#   'ریشه': 13,
#   'مشکلات': 20,
#   'منازعات': 0,
#   'نبود': 71,
#   'صحیح': 2,
#   'یکدیگر': 35,
#   'شناخت': 14,
#   'ناقص': 0,
#   'مشترک': 14,
#   'جوامع': 3,
#   'باز': 102,
#   'گفتمان': 0,
#   'نظرات': 1,
#   'رسانه': 2,
#   'بریتانیا': 10,
#   'چهره': 42,
#   'آیینه': 2,
#   'مطبوعات': 4,
#   'توسط': 18,
#   'آقایان': 1,
#   'پل': 27,
#   'بیکر': 0,
#   'کاستاس': 0,
#   'گابریلاتوس': 0,
#   'تونی': 5,
#   'مک': 9,
#   'انری': 0,
#   'نوشته_شده_است': 25,
#   'بهر': 0,
#   'ازپژوهش': 0,
#   'رایزنی': 0,
#   'جمهوری': 4,
#   'نظران': 2,
#   'بزرگان': 7,
#   'صاحب': 23,
#   'حوزه': 12,
#   'آگاهی': 5,
#   'خوانندگان': 15,
#   'موثر': 1,
#   'مفید': 2,
#   'واقع': 36,
#   'اختلالات': 2,
#   'مصرف': 1,
#   'مواد': 5,
#   'مشاوره': 0,
#   'اعتیاد': 2,
#   'فورد': 0,
#   'بروکس': 0,
#   'بیل': 1,
#   'ام': 66,
#   'سی': 39,
#   'هنری': 12,
#   'کتابی': 27,
#   'آخرین': 48,
#   'روش': 8,
#   'ترک': 39,
#   'موادمخدر': 0,
#   'الکل': 3,
#   'آشنا': 41,
#   'نهایی': 3,
#   'نگارش': 22,
#   'رفتارهای': 4,
#   'مشکل': 14,
#   'ساز': 8,
#   'اعتیادآور': 0,
#   'تغییر': 26,
#   'سازگارانه': 0,
#   'آموخته_شود': 0,
#   'پروفسور': 10,
#   'دانشکده': 5,
#   'کارمند': 7,
#   'دانشگاه': 39,
#   'شیپنزبورگ': 0,
#   'پنسیلوانیا': 0,
#   'ایشان': 6,
#   'برنامه': 9,
#   'بهداشت': 0,
#   'روانی': 20,
#   'بالینی': 0,
#   'همچنین': 26,
#   'عملی': 6,
#   'کارآموزی': 0,
#   'تخصصی': 0,
#   'دپارتمان': 0,
#   'ریزی': 4,
#   'سرپرستی': 1,
#   'سرویس': 1,
#   'آموزشی': 2,
#   'درمان': 6,
#   'جویان': 0,
#   'درکمپ': 0,
#   'آژانس': 0,
#   'مدارس': 0,
#   'منطقه': 8,
#   'جنوب': 6,
#   'مرکزی': 5,
#   'ارائه': 3,
#   'داد': 118,
#   'دکترای': 1,
#   'رشته': 21,
#   'ویلیام': 5,
#   'ماری': 9,
#   'فوق': 9,
#   'لیسانس': 5,
#   'ویرجینیا': 3,
#   'گرایش': 1,
#   'روان': 31,
#   'ریچموند': 0,
#   'دریافت': 34,
#   'کرده_است': 95,
#   'رئیس': 14,
#   'تحصیلات': 5,
#   'تکمیلی': 1,
#   'پژوهشی': 1,
#   'تگزاس': 0,
#   'آموزش': 1,
#   'داکوتای': 0,
#   'جنوبی': 9,
#   'مدت': 43,
#   'سال': 469,
#   'مشاور': 0,
#   'بوده_است': 25,
#   'تجربه': 41,
#   'گروهی': 9,
#   'زوجی': 5,
#   'خانوادگی': 15,
#   'سوء': 4,
#   'دانشگاهها': 0,
#   'سلامتی': 2,
#   'مراکز': 2,
#   'جست': 13,
#   'وجوی': 7,
#   'معنا': 3,
#   'رهیافتی': 0,
#   'معناشناختی': 0,
#   'اطلاعات': 8,
#   'نرگس': 2,
#   'نشاط': 1,
#   'امروزه': 2,
#   'هرکس': 6,
#   'محتوا': 2,
#   'متن': 15,
#   'سروکار': 1,
#   'نیازمند': 2,
#   'ابزاری': 1,
#   'علمی': 2,
#   'بتواند': 16,
#   'پیام': 10,
#   'مخابره': 0,
#   'انتقالی': 2,
#   'داشته_باشد': 21,
#   'سوال': 7,
#   'پرسیده_شود': 0,
#   'احساس': 61,
#   'نیاز': 7,
#   'بوجود': 0,
#   'سبب': 13,
#   'تشدید': 1,
#   'پیامی': 1,
#   'ارسال': 1,
#   'نهفته': 6,
#   'باید': 120,
#   'موضوعی': 4,
#   'برخورد': 13,
#   'معناشناسی': 0,
#   'گونه': 63,
#   'مورد': 52,
#   'پی': 36,
#   'کشف': 11,
#   'چگونگی': 6,
#   'سازماندهی': 1,
#   'بررسی': 14,
#   'تاثیر': 11,
#   'معنایی': 8,
#   'گیرنده': 0,
#   'خواننده': 55,
#   'شنونده': 1,
#   'دانست': 39,
#   'کجا': 20,
#   'سپس': 25,
#   'بازتولید': 0,
#   'تفسیر': 3,
#   'فهمیده': 1,
#   'بنابراین': 13,
#   'مساله': 2,
#   'محوری': 7,
#   'معناست': 2,
#   'مستقیم': 5,
#   'غیرمستقیم': 1,
#   'پیوند': 10,
#   'جستجوی': 8,
#   'امکانات': 2,
#   'تحقق': 4,
#   'پیوستگی': 1,
#   'ماهیت': 1,
#   'آزمایش': 3,
#   'اعتبار': 1,
#   'دانیم': 3,
#   'آیا': 39,
#   'مفهوم': 6,
#   'رها': 17,
#   'یعنی': 58,
#   'بدانیم': 2,
#   'آنجا': 52,
#   'خواهیم_معنا': 0,
#   'قیمتی': 1,
#   'قیمت': 3,
#   'خواهدشد': 0,
#   'مبارزه': 14,
#   'راهبرد': 0,
#   'آغاز': 77,
#   'اندوه': 9,
#   'بالابان': 0,
#   'رجبی': 0,
#   'مناسب': 11,
#   'گروه': 28,
#   'سنی': 6,
#   'اولین': 72,
#   'جشنواره': 5,
#   'سپیدار': 0,
#   'برگزیده': 12,
#   'انتخاب': 42,
#   'قاچاق': 3,
#   'غیر': 25,
#   'قانونی': 5,
#   'پرندگان': 0,
#   'ارزشمندی': 1,
#   'کشورهای': 6,
#   'حاشیه': 8,
#   'خلیج': 1,
#   'فارس': 1,
#   'مندو': 0,
#   'پسری': 17,
#   'نوجوان': 17,
#   'لنجی': 0,
#   'نام': 248,
#   'شبوت': 0,
#   'ناخدا': 2,
#   'سمیر': 0,
#   'کار': 197,
#   'روزهایی': 5,
#   'شارجه': 0,
#   'بروند': 6,
#   'مسافری': 3,
#   'غریبه': 16,
#   'جعبه': 4,
#   'مرموز': 9,
#   'همسفر': 1,
#   'تعدادی': 7,
#   'پرنده': 3,
#   'داخل': 25,
#   'زندانی': 18,
#   'دلش': 9,
#   'خواهد_پرنده': 0,
#   'نجات': 17,
#   'همکاری': 8,
#   'کردن': 85,
#   'همکاران': 0,
#   'دیگرش': 5,
#   'مرد': 129,
#   'خشمگین': 3,
#   'اما': 375,
#   'آخر': 21,
#   'ماموران': 1,
#   'گشت': 19,
#   'دریایی': 9,
#   'خبر': 30,
#   'قاچاقچی': 0,
#   'بگیرند': 11,
#   'دهند': 26,
#   'زیبا': 27,
#   'اصطلاحات': 2,
#   'کلمات': 19,
#   'بومی': 8,
#   'خوبی': 48,
#   'جغرافیای': 2,
#   'مهرتابناک': 0,
#   'جلد': 29,
#   'اول': 91,
#   'شمه': 0,
#   'احوالات': 0,
#   'آیت': 1,
#   'الله': 4,
#   'حاج': 2,
#   'سیدعلی': 0,
#   'قاضی': 3,
#   'آثار': 107,
#   'علامه': 0,
#   'محمدحسین': 0,
#   'حسینی': 4,
#   'طهرانی': 0,
#   'اضافاتی': 0,
#   'سیدمحمدمحسن': 0,
#   'تهرانی': 6,
#   'مدیریت': 2,
#   'خدمات': 0,
#   'مشتری': 3,
#   'ژاک': 2,
#   'هاروویتز': 0,
#   'استاد': 27,
#   'بازاریابی': 0,
#   'الملل': 1,
#   'لوزان': 0,
#   'سوییس': 0,
#   'تخصص': 0,
#   'وی': 57,
#   'ارتقای': 1,
#   'رضایت': 4,
#   'برارائه': 0,
#   'تفکیک': 0,
#   'تقویت': 2,
#   'وفاداری': 3,
#   'نتیجه': 19,
#   'خدماتی': 1,
#   'مدرسه': 34,
#   'عالی': 13,
#   'بازرگانی': 0,
#   'پاریس': 20,
#   'فرانسه': 51,
#   'فارغ': 8,
#   'التحصیل': 4,
#   'شد': 394,
#   'دکترا': 0,
#   'کلمبیا': 8,
#   'نیویورک': 25,
#   'پاداش': 1,
#   'تحصیلی': 0,
#   'شامل': 4,
#   'هزینه': 2,
#   'ساموئل': 3,
#   'بردنفمن': 0,
#   'کلی': 18,
#   'آموزشگاه': 0,
#   'امریکا': 23,
#   'فکر': 134,
#   'توسعه': 1,
#   'فعالیت': 20,
#   'مجال': 1,
#   'اندیشیدن': 0,
#   'مزایای': 1,
#   'طولی': 2,
#   'اضافی': 0,
#   'دستگاه': 13,
#   'بخرید': 0,
#   'کارش': 15,
#   'محصولاتی': 0,
#   'معین': 0,
#   'مشتریانی': 0,
#   'فروشنده': 2,
#   'فروش': 20,
#   'تواند': 68,
#   'پیشنهادش': 0,
#   'قراردادهای': 0,
#   'مربوط': 15,
#   'تعمیرات': 0,
#   'احتیاطی': 0,
#   'مستمر': 0,
#   'مشتریان': 0,
#   'درنهایت': 2,
#   'محصولات': 1,
#   'تولیدشده': 0,
#   'وسیله': 4,
#   'رأیت': 0,
#   'دین': 6,
#   'تألیف': 2,
#   'اکبر': 2,
#   'عالمیان': 0,
#   'رفتار': 17,
#   'العظمی': 0,
#   'بروجردی': 1,
#   'تحریر': 0,
#   'درآمده': 7,
#   'بخش': 59,
#   'ابتدا': 21,
#   'مرجع': 1,
#   'عظیم': 10,
#   'القدر': 0,
#   'تولد': 6,
#   'رحلت': 0,
#   'دوم': 77,
#   'رابطه': 29,
#   'مقوله': 0,
#   'محقق': 4,
#   'سوم': 39,
#   'رهبری': 2,
#   'امت': 0,
#   ...}}

# %% [markdown]
# ### Create bag of word

# %%
import pandas as pd

# %%
df = pd.DataFrame(categories_data)
df = df.transpose()

# %%
df
# Out:
#                          total  ساختار  نظریه   های  جامعه  شناسی  ایران  \
# total                   496563      50    172  6139    648    378    359
# جامعه شناسی              93900      33    130  1517    453    292    190
# کلیات اسلام              65265       2     17   612     72     44     34
# داستان کودک و نوجوانان   40765       0      1   595      4      0     21
# داستان کوتاه             91437       3      1  1072     33      5     51
# مدیریت و کسب و کار       82417       7     20  1192     35     31     23
# رمان                    122779       5      3  1151     51      6     40
#
#                         نوشته  ابوالفضل  رمضانی  ...  بزک  جودانه  کتابفروش  \
# total                     936         8       7  ...    1       1         1
# جامعه شناسی               156         3       1  ...    0       0         0
# کلیات اسلام               110         2       0  ...    0       0         0
# داستان کودک و نوجوانان    155         2       6  ...    0       0         0
# داستان کوتاه              171         1       0  ...    1       1         1
# مدیریت و کسب و کار        174         0       0  ...    0       0         0
# رمان                      170         0       0  ...    0       0         0
#
#                         کماندوهای  قدرش  بهروان  ستمگر  خواهی_هود  بنوشند  \
# total                           1     1       1      1          1       1
# جامعه شناسی                     0     0       0      0          0       0
# کلیات اسلام                     0     0       0      0          0       1
# داستان کودک و نوجوانان          0     0       1      1          1       0
# داستان کوتاه                    1     1       0      0          0       0
# مدیریت و کسب و کار              0     0       0      0          0       0
# رمان                            0     0       0      0          0       0
#
#                         اهلش
# total                      1
# جامعه شناسی                0
# کلیات اسلام                1
# داستان کودک و نوجوانان     0
# داستان کوتاه               0
# مدیریت و کسب و کار         0
# رمان                       0
#
# [7 rows x 29284 columns]

# %% [markdown]
# ### calculate p(c)

# %%
sum_book = {"total" : 0}
for book in books_train_csv:
    if book["categories"] not in sum_book.keys():
        sum_book[book["categories"]] = 0
    sum_book[book["categories"]] += 1
    sum_book["total"] += 1

# %%
p_c = dict()
for category in sum_book.keys():
    p_c[category] = sum_book[category] / sum_book["total"]

# %% [markdown]
# ### calculate p(x)

# %%
p_x = dict()

for word in categories_data["total"].keys():
    p_x[word] = categories_data["total"][word] / categories_data["total"]["total"]

# %% [markdown]
# ### calculate p(x|c)

# %%
p_x_c = dict()

for category in categories_data.keys():
    p_x_c[category] = dict()
    for word in categories_data[category].keys():
        p_x_c[category][word] = categories_data[category][word] / categories_data[category]["total"]
